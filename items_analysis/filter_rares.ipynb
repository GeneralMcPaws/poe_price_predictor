# %%
# %%html
# <style>
# .cm-s-ipython .CodeMirror-matchingbracket { color: LimeGreen !important;}
# </style>
# Out:
# <style>
# .cm-s-ipython .CodeMirror-matchingbracket { color: LimeGreen !important;}
# </style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import pprint
from scipy import stats
import random
from pandas.tools.plotting import table

# %%
import pathlib

# %%
from sklearn import preprocessing

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %%
def pre_process_df(df):
    
    #Drop unwanted columns
    df_dropped = df.drop(columns=['Unnamed: 0','item_name',
                                  'stash_id','stash_feed',
                                  '_id',
                                  'date_month','date_year','date',
                                  'league','rarity',
                                  'price_currency','price_raw',
                                  'time_minutes','time'])
    
    # delete columns with no values in them, which means only zero
    proc_df = df_dropped.loc[:,(df!=0).any (axis=0)]
    
    # Clean up of data. 
    ## Prices were imported as 'Object' not 'float'. We need to convert them to float.
    proc_df[['price_amount']] = pd.to_numeric(proc_df['price_amount'],errors='coerce')
    
    # Remove rows where price_amount is NaN or zero
    proc_df = proc_df[pd.notnull(proc_df['price_amount'])]
    proc_df = proc_df.loc[proc_df['price_amount']!=0]
    
    return proc_df

def compute_corr(df,method='kendall',filename=''):
    
    #min_periods = int(len(df))*0.1
    cols = list(df.filter(regex='(Attacks per Second|Energy Shield|Elemental Damage|Critical Strike Chance|Physical Damage|influence|Armour|sockets_number|linked_sockets|Evasion Rating|item_category)|(?=^co_|ex_|im_|en_$)(^.*$)').columns.values)
    df[cols] = df[cols].replace({0:np.nan, 0.0:np.nan})
    #df[df.filter(regex='(?=^co_|ex_|im_|en_$)(^.*$)') <= 0.0] = np.nan
    corr = df.corr(method)
    corr = corr.dropna('columns',how='all')
    corr = corr.dropna('rows',how='all')
    df = df.fillna(0)
    
    return corr

def remove_outliers_IQR(item_dataframe,column_label = 'price_amount',high_quantile=0.75):
    '''Function removes outliers from a dataframe along the price_amount column by default.

    Input:
        df: pandas DataFrame
        column_label: along which column to check for outliers(default = 'price_amount')
        high_quantile: high-end quantile to use on boxplot'''
    
    Q1 = item_dataframe[column_label].quantile(1-high_quantile)
    Q3 = item_dataframe[column_label].quantile(high_quantile)
    IQR = Q3 - Q1
    new_df = item_dataframe[~((item_dataframe[column_label] < (Q1 - 1.5 * IQR))|(item_dataframe[column_label] > (Q3 + 1.5 * IQR)))]
    
    return new_df

def remove_outliers_zscore(item_dataframe,column_labels = ['price_amount'],threshold=3,show_results=False):
    '''Function removes outliers using z-score from a dataframe along the price_amount column by default.

    Input:
        df: pandas DataFrame
        column_label: along which columns to check for outliers(default = ['price_amount'])
        show_results: show results before and after removing outliers(default = False)
        size: vertical and horizontal size of the plot'''
    
    z_score = np.abs(stats.zscore(item_dataframe[column_labels]))
    new_df = item_dataframe[(z_score < threshold)]
    if show_results:
        data_outliers_index = np.where(z_score > threshold)[0]
        print('Data outliers for "{}":'.format(item_dataframe['item_name'][0]))
        for id in data_outliers_index:
              print('index: {:<10d}{}: {:<10f}'.format(id,column_labels[0],item_dataframe.iloc[id][column_labels[0]]))
        print('Removed {} rows'.format(item_dataframe.shape[0]-new_df.shape[0]))
    return new_df


def produce_decision_dataframe(item_df,correlations_df=pd.DataFrame,incl_outliers=True,method='z-score',threshold=2,quantile=0.8):
    
    d_df = item_df
    
    if not incl_outliers:
        if method == 'z-score' : 
            d_df = remove_outliers_zscore(d_df,threshold=threshold)
        elif method == 'IQR' :
            d_df = remove_outliers_IQR(d_df,high_quantile=quantile)
        else:
            raise Exception('\t\tWrong outlier mode. Valid options mode = [z-score | IQR]')
    
    if correlations_df.empty:
        columns = ['item_name','feature','corr_value','no_features','transactions','std']
        correlations_df =  pd.DataFrame(columns=columns)
    
    corr=compute_corr(d_df,method='kendall')
    #corr_filtered = corr['price_amount'].filter(regex='(item_category|corrupted|Attacks per Second|Energy Shield|Elemental Damage|Critical Strike Chance|Physical Damage|influence|Armour|sockets_number|linked_sockets|Quality|Evasion Rating)|(?=^co_|ex_|im_|en_$)(^.*$)').drop(labels=['ex_conv_rate'],axis=0).dropna()
    corr_filtered = corr['price_amount'].filter(regex='(date_day|item_category|corrupted|Attacks per Second|Energy Shield|Elemental Damage|Critical Strike Chance|Physical Damage|influence|Armour|sockets_number|linked_sockets|Quality|Evasion Rating)|(?=^co_|ex_|im_|en_$)(^.*$)').dropna()
    for row in corr_filtered.index:
        correlations_df = correlations_df.append({'item_name':d_df['item_name'].unique()[0],
                                'feature':row,
                                'corr_value': corr_filtered[row],
                                'no_features':len(corr_filtered),
                                'transactions':d_df.groupby('item_name')['item_name'].count().values[0],
                                'std':d_df['price_amount'].describe()['std']},ignore_index=True)
    
    return correlations_df

def produce_corr_based_df(df_per_item_name,method='z-score',threshold=2,quantile=0.8):
    
    columns = ['item_name','feature','corr_value','no_features','transactions','std']

    df =  pd.DataFrame(columns=columns)

    count = 0
    for dataF in df_per_item_name:
        count= count+1
        if count%200==0:
            print("Processed {} item_names".format(count))
        item_df = df_per_item_name[dataF]
        df = produce_decision_dataframe(item_df,df,incl_outliers=False,method=method,threshold=threshold,quantile=quantile)
        
    return df

def filter_decision_df(df, days=7, min_corr=0.1, min_no_features=2, min_std=5.0):
    
    min_trx = days*24
    
    df_filtered = df[(abs(df['corr_value'])>=min_corr) & \
                                          (df['transactions'] > min_trx) & \
                                          (df['std'] > min_std)]
    
    df_filtered['no_features'] = df_filtered.groupby('item_name')['item_name'].transform('count')
    df_filtered = df_filtered[df_filtered['no_features'] >= min_no_features]
    
    return df_filtered

def convert_column_values_string_to_rankInt(df) -> pd.DataFrame:
    for column in df.columns:
        if df[column].dtype == type(object):
            le = preprocessing.LabelEncoder()
            df[column] = le.fit_transform(df[column].astype(str))

    return df

# %% [markdown]
# # Processing all the rare item categories

# %%
directory = "C:/Users/Digi/Desktop/poe_price_predictor/record_creator/record_creator/csv/rare/"
files_to_process = [x for x in glob.glob(directory+'*_values.csv')]

df_per_category = {}

for f in files_to_process:
    
    print("Processing start : {}".format(f[81:]))
    
    df = pd.read_csv(f)
    
    proc_category_df = pre_process_df(df)
        
    print("Processing end : {}".format(f[81:]))
    
    category=proc_category_df['item_category'].unique()[0]
    df_per_category[category] = proc_category_df
# Out:
# Processing start : wand_values.csv
# Processing end : wand_values.csv

# %%
for key,category_df in df_per_category.items():
    "{}_columns = {}".format(key,category_df.shape[1])
    run_all_statistics(category_df)
# Out:
# 'wand_columns = 126'
# Correlations with outliers
# Removing outliers zscore
# Removing outliers IQR
# Correlations without outliers zscore
# Correlations without outliers IQR

# %% [markdown]
# # Statistics

# %% [markdown]
# ## With outliers

# %% [markdown]
# ### Data percentage present per column

# %%
((proc_category_df!=0).sum()/len(proc_category_df)*100)
# Out:
# date_day                                               100.000000
# ex_conv_rate                                           100.000000
# item_category                                          100.000000
# item_level                                             100.000000
# socket_colors                                          100.000000
# price_amount                                            99.766039
# time_hours                                              90.280516
# days_in_snapshot                                        64.917302
# ex_# to maximum life                                    39.551713
# ex_# to maximum mana                                    22.985994
# ex_# to maximum energy shield                           22.621790
# ex_adds # physical damage to attacks                    22.201373
# ex_#% to lightning resistance                           19.451240
# ex_#% to fire resistance                                19.186005
# ex_#% to cold resistance                                18.885537
# ex_#% to global critical strike multiplier              17.440599
# ex_# to intelligence                                    15.420061
# ex_#% to all elemental resistances                      15.379682
# ex_# to strength                                        15.315947
# ex_# to dexterity                                       15.018250
# ex_#% increased global critical strike chance           14.933533
# ex_# to accuracy rating                                 14.769245
# ex_#% increased maximum energy shield                   14.408605
# ex_# to all attributes                                  13.522244
# ex_#% increased rarity of items found                   13.074907
# ex_#% increased spell damage                            13.044425
# corrupted                                               12.831445
# ex_#% increased armour                                  12.532956
# ex_#% increased evasion rating                          12.343333
# im_# to all attributes                                  10.802990
# ex_adds # lightning damage to attacks                   10.735691
# ex_adds # fire damage to attacks                        10.107836
# im_# to strength and dexterity                           9.948695
# ex_adds # cold damage to attacks                         9.892877
# ex_#% increased mana regeneration rate                   9.868333
# im_# to strength and intelligence                        9.657728
# im_# to dexterity and intelligence                       9.420204
# im_# to intelligence                                     9.170012
# im_# to dexterity                                        8.983555
# ex_# life regenerated per second                         8.980784
# im_# to strength                                         8.879837
# im_#% increased rarity of items found                    8.145887
# ex_#% increased cast speed                               6.193044
# im_#% increased mana regeneration rate                   6.120995
# ex_#% increased lightning damage                         5.858135
# ex_#% increased fire damage                              5.774606
# im_# life regenerated per second                         5.755208
# ex_# life gained for each enemy hit by your attacks      5.550145
# ex_#% increased cold damage                              5.383483
# ex_# life gained on kill                                 5.377940
# dtype: float64

# %% [markdown]
# ### Compute correlations for different methods

# %%
corr_kendall = compute_corr(proc_category_df,method='kendall')
corr_spear = compute_corr(proc_category_df,method='spearman')
corr_pears = compute_corr(proc_category_df,method='pearson')

# %%
corr_spear['price_amount'].sort_values(ascending=False)
(corr_spear['price_amount']>0).sum()
(corr_kendall['price_amount']>0).sum()
(corr_pears['price_amount']>0).sum()
# Out:
# price_amount                                                        1.000000
# ex_minions have #% increased movement speed                         0.662454
# ex_#% increased attack speed                                        0.630827
# ex_#% increased quantity of items found                             0.593084
# ex_#% of life regenerated per second                                0.501488
# co_#% increased quantity of items found                             0.418741
# item_level                                                          0.358838
# ex_damage penetrates #% elemental resistances                       0.342013
# ex_# to maximum life                                                0.320331
# ex_#% increased movement speed                                      0.320085
# ex_gain #% of physical damage as extra lightning damage             0.308968
# ex_#% increased elemental damage with attack skills                 0.294738
# ex_#% to global critical strike multiplier                          0.280317
# im_#% of life regenerated per second                                0.276573
# ex_gain #% of non-chaos damage as extra chaos damage                0.271934
# ex_#% of block chance applied to spells                             0.258682
# ex_#% chance to gain a power, frenzy or endurance charge on kill    0.250702
# ex_gain #% of physical damage as extra cold damage                  0.248950
# ex_items and gems have #% reduced attribute requirements            0.243519
# ex_#% increased area of effect                                      0.229162
# ex_#% to lightning resistance                                       0.217644
# ex_#% increased spell damage                                        0.214778
# ex_#% to fire resistance                                            0.211811
# ex_#% to cold resistance                                            0.206401
# ex_# to total mana cost of skills                                   0.205131
# ex_adds # physical damage to attacks                                0.204640
# co_discipline has #% increased aura effect                          0.202145
# ex_# to all attributes                                              0.197691
# ex_#% to all elemental resistances                                  0.197234
# ex_# to strength                                                    0.181895
#                                                                       ...
# co_#% increased attack and cast speed                               0.003536
# ex_#% of maximum life per second to maximum life leech rate        -0.001258
# co_#% increased attack speed                                       -0.002155
# co_#% increased attributes                                         -0.003692
# ex_#% of cold damage leeched as life                               -0.004510
# co_# to dexterity                                                  -0.004675
# im_# life regenerated per second                                   -0.012989
# co_#% chance to freeze, shock and ignite                           -0.013658
# co_# to all attributes                                             -0.014507
# co_#% increased area of effect                                     -0.014644
# co_#% increased global defences                                    -0.016389
# co_#% chance to block                                              -0.017733
# co_# life regenerated per second                                   -0.018178
# co_hatred has #% increased aura effect                             -0.018679
# co_#% increased cold damage                                        -0.021047
# co_#% increased mana regeneration rate                             -0.024023
# co_#% increased elemental damage with attack skills                -0.038010
# days_in_snapshot                                                   -0.046214
# co_#% increased maximum mana                                       -0.052917
# co_#% increased rarity of items found                              -0.056113
# ex_#% of physical damage leeched as life                           -0.059462
# co_#% increased intelligence                                       -0.067466
# co_#% increased dexterity                                          -0.071079
# co_wrath has #% increased aura effect                              -0.084265
# influence                                                          -0.100045
# co_grace has #% increased aura effect                              -0.106491
# co_#% of life regenerated per second                               -0.132419
# ex_#% additional physical damage reduction                         -0.185348
# co_determination has #% increased aura effect                      -0.253469
# co_#% increased fish bite sensitivity                                    NaN
# Name: price_amount, Length: 128, dtype: float64
# 99
# 101
# 92

# %% [markdown]
# ### Basic describe and put all statistics in a dataframe

# %%
def run_all_statistics(df):
    item_category = df['item_category'].unique()[0]
    
    print("Correlations with outliers")
    corr_kendall = compute_corr(df,method='kendall')
    corr_pears = compute_corr(df,method='pearson')
    corr_spear = compute_corr(df,method='spearman')
    column_statistics_o = df.describe().transpose()
    column_statistics_o['median'] = df.median()
    column_statistics_o['variance'] = df.var()
    column_statistics_o['count'] = (df.notna()).sum()
    column_statistics_o['corr_kend_price'] = corr_kendall['price_amount'].round(3)
    column_statistics_o['corr_pears_price'] =corr_pears['price_amount'].round(3)
    column_statistics_o['corr_spear_price'] =corr_spear['price_amount'].round(3)
    column_statistics_o['percentage_to_rows'] = (df.notna()).sum()/len(df)*100
    column_statistics_o.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_o.csv'.format(item_category),sep='^')
    
    print("Removing outliers zscore")
    df_zscore_1 = remove_outliers_zscore(df,threshold=1)
    df_zscore_2 = remove_outliers_zscore(df,threshold=2)
    df_zscore_3 = remove_outliers_zscore(df,threshold=3)

    print("Removing outliers IQR")
    df_IQR_70 = remove_outliers_IQR(df,high_quantile=0.7)
    df_IQR_80 = remove_outliers_IQR(df,high_quantile=0.8)
    df_IQR_90 = remove_outliers_IQR(df,high_quantile=0.9)
    
    print("Correlations without outliers zscore")
    corr_kendall_zscore_2 = compute_corr(df_zscore_2,method='kendall')
    corr_spear_zscore_2 = compute_corr(df_zscore_2,method='spearman')
    corr_pears_zscore_2 = compute_corr(df_zscore_2,method='pearson')

    column_statistics_zscore_2 = df_zscore_2.describe().transpose()
    column_statistics_zscore_2['median'] = df_zscore_2.median()
    column_statistics_zscore_2['variance'] = df_zscore_2.var()
    column_statistics_zscore_2['count'] = (df_zscore_2.notna()).sum()
    column_statistics_zscore_2['corr_kend_price'] = corr_kendall_zscore_2['price_amount'].round(3)
    column_statistics_zscore_2['corr_pears_price'] =corr_pears_zscore_2['price_amount'].round(3)
    column_statistics_zscore_2['corr_spear_price'] =corr_spear_zscore_2['price_amount'].round(3)
    column_statistics_zscore_2['percentage_to_rows'] = (df_zscore_2.notna()).sum()/len(df_zscore_2)*100
    column_statistics_zscore_2.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_zscore_2.csv'.format(item_category),sep='^')

    corr_kendall_zscore_1 = compute_corr(df_zscore_1,method='kendall')
    corr_spear_zscore_1 = compute_corr(df_zscore_1,method='spearman')
    corr_pears_zscore_1 = compute_corr(df_zscore_1,method='pearson')

    column_statistics_zscore_1 = df_zscore_1.describe().transpose()
    column_statistics_zscore_1['median'] = df_zscore_1.median()
    column_statistics_zscore_1['variance'] = df_zscore_1.var()
    column_statistics_zscore_1['count'] = (df_zscore_1.notna()).sum()
    column_statistics_zscore_1['corr_kend_price'] = corr_kendall_zscore_1['price_amount'].round(3)
    column_statistics_zscore_1['corr_pears_price'] =corr_pears_zscore_1['price_amount'].round(3)
    column_statistics_zscore_1['corr_spear_price'] =corr_spear_zscore_1['price_amount'].round(3)
    column_statistics_zscore_1['percentage_to_rows'] = (df_zscore_1.notna()).sum()/len(df_zscore_1)*100
    column_statistics_zscore_1.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_zscore_1.csv'.format(item_category),sep='^')
    
    corr_kendall_zscore_3 = compute_corr(df_zscore_3,method='kendall')
    corr_spear_zscore_3 = compute_corr(df_zscore_3,method='spearman')
    corr_pears_zscore_3 = compute_corr(df_zscore_3,method='pearson')

    column_statistics_zscore_3 = df_zscore_3.describe().transpose()
    column_statistics_zscore_3['median'] = df_zscore_3.median()
    column_statistics_zscore_3['variance'] = df_zscore_3.var()
    column_statistics_zscore_3['count'] = (df_zscore_3.notna()).sum()
    column_statistics_zscore_3['corr_kend_price'] = corr_kendall_zscore_3['price_amount'].round(3)
    column_statistics_zscore_3['corr_pears_price'] =corr_pears_zscore_3['price_amount'].round(3)
    column_statistics_zscore_3['corr_spear_price'] =corr_spear_zscore_3['price_amount'].round(3)
    column_statistics_zscore_3['percentage_to_rows'] = (df_zscore_3.notna()).sum()/len(df_zscore_3)*100
    column_statistics_zscore_3.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_zscore_3.csv'.format(item_category),sep='^')

    print("Correlations without outliers IQR")
    corr_kendall_IQR_70 = compute_corr(df_IQR_70,method='kendall')
    corr_spear_IQR_70 = compute_corr(df_IQR_70,method='spearman')
    corr_pears_IQR_70 = compute_corr(df_IQR_70,method='pearson')

    column_statistics_IQR_70 = df_IQR_70.describe().transpose()
    column_statistics_IQR_70['median'] = df_IQR_70.median()
    column_statistics_IQR_70['variance'] = df_IQR_70.var()
    column_statistics_IQR_70['count'] = (df_IQR_70.notna()).sum()
    column_statistics_IQR_70['corr_kend_price'] = corr_kendall_IQR_70['price_amount'].round(3)
    column_statistics_IQR_70['corr_pears_price'] =corr_pears_IQR_70['price_amount'].round(3)
    column_statistics_IQR_70['corr_spear_price'] =corr_spear_IQR_70['price_amount'].round(3)
    column_statistics_IQR_70['percentage_to_rows'] = (df_IQR_70.notna()).sum()/len(df_IQR_70)*100
    column_statistics_IQR_70.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_IQR_70.csv'.format(item_category),sep='^')

    corr_kendall_IQR_80 = compute_corr(df_IQR_80,method='kendall')
    corr_spear_IQR_80 = compute_corr(df_IQR_80,method='spearman')
    corr_pears_IQR_80 = compute_corr(df_IQR_80,method='pearson')

    column_statistics_IQR_80 = df_IQR_80.describe().transpose()
    column_statistics_IQR_80['median'] = df_IQR_80.median()
    column_statistics_IQR_80['variance'] = df_IQR_80.var()
    column_statistics_IQR_80['count'] = (df_IQR_80.notna()).sum()
    column_statistics_IQR_80['corr_kend_price'] = corr_kendall_IQR_80['price_amount'].round(3)
    column_statistics_IQR_80['corr_pears_price'] =corr_pears_IQR_80['price_amount'].round(3)
    column_statistics_IQR_80['corr_spear_price'] =corr_spear_IQR_80['price_amount'].round(3)
    column_statistics_IQR_80['percentage_to_rows'] = (df_IQR_80.notna()).sum()/len(df_IQR_80)*100
    column_statistics_IQR_80.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_IQR_80.csv'.format(item_category),sep='^')

    corr_kendall_IQR_90 = compute_corr(df_IQR_90,method='kendall')
    corr_spear_IQR_90 = compute_corr(df_IQR_90,method='spearman')
    corr_pears_IQR_90 = compute_corr(df_IQR_90,method='pearson')

    column_statistics_IQR_90 = df_IQR_90.describe().transpose()
    column_statistics_IQR_90['median'] = df_IQR_90.median()
    column_statistics_IQR_90['variance'] = df_IQR_90.var()
    column_statistics_IQR_90['count'] = (df_IQR_90.notna()).sum()
    column_statistics_IQR_90['corr_kend_price'] = corr_kendall_IQR_90['price_amount'].round(3)
    column_statistics_IQR_90['corr_pears_price'] =corr_pears_IQR_90['price_amount'].round(3)
    column_statistics_IQR_90['corr_spear_price'] =corr_spear_IQR_90['price_amount'].round(3)
    column_statistics_IQR_90['percentage_to_rows'] = (df_IQR_90.notna()).sum()/len(df_IQR_90)*100
    column_statistics_IQR_90.round(3).to_csv('C:/Users/Digi/Desktop/rares/{}_stats_IQR_90.csv'.format(item_category),sep='^')

# %%
column_statistics_o = proc_category_df.describe().transpose()
column_statistics_o['median'] = proc_category_df.median()
column_statistics_o['variance'] = proc_category_df.var()
column_statistics_o['count'] = (proc_category_df.notna()).sum()
column_statistics_o['corr_kend_price'] = corr_kendall['price_amount'].round(3)
column_statistics_o['corr_pears_price'] =corr_pears['price_amount'].round(3)
column_statistics_o['corr_spear_price'] =corr_spear['price_amount'].round(3)
column_statistics_o['percentage_to_rows'] = (proc_category_df.notna()).sum()/len(proc_category_df)*100

# %%
pd.set_option('display.max_rows',171)
column_statistics_o
# Out:
#                                                      count        mean  \
# co_# life regenerated per second                      1052    3.025665
# co_# to all attributes                                1125   13.179556
# co_# to dexterity                                      926   25.091793
# co_# to dexterity and intelligence                     949   20.182297
# co_# to intelligence                                  1070   25.165421
# co_# to maximum number of zombies                      797    1.000000
# co_# to strength                                      1004   25.135458
# co_# to strength and dexterity                         962   20.019751
# co_# to strength and intelligence                     1053   20.155745
# co_#% additional physical damage reduction             290    5.017241
# co_#% chance to block                                   97    4.577320
# co_#% chance to freeze, shock and ignite               525    5.040000
# co_#% chance to gain a frenzy charge on kill           143    1.000000
# co_#% chance to gain a power charge on kill            124    1.000000
# co_#% chance to gain an endurance charge on kill       148    1.000000
# co_#% increased area of effect                         338    6.505917
# co_#% increased attack and cast speed                  807    8.092937
# co_#% increased attack damage                          815   25.127607
# co_#% increased attack speed                           148    8.972973
# co_#% increased attributes                             434   14.025346
# co_#% increased chaos damage                           723   25.011065
# co_#% increased cold damage                            774   25.179587
# co_#% increased damage                                 479   30.242171
# co_#% increased dexterity                              267    4.985019
# co_#% increased elemental damage with attack sk...     180   22.077778
# co_#% increased fire damage                            776   24.914948
# co_#% increased fish bite sensitivity                    2   39.500000
# co_#% increased global critical strike chance          906   45.060706
# co_#% increased global defences                        654   19.920489
# co_#% increased global physical damage                 841   25.313912
# co_#% increased intelligence                           280    5.050000
# co_#% increased lightning damage                       858   25.101399
# co_#% increased mana regeneration rate                1231   25.803412
# co_#% increased maximum life                           896   10.104911
# co_#% increased maximum mana                           652   25.018405
# co_#% increased movement speed                          73    9.164384
# co_#% increased quantity of items found               1636    8.377139
# co_#% increased rarity of items found                 1135   16.647577
# co_#% increased spell damage                           985   25.426396
# co_#% increased strength                               274    4.923358
# co_#% of block chance applied to spells                118   22.466102
# co_#% of cold damage from hits taken as fire da...      88    1.000000
# co_#% of cold damage from hits taken as lightni...      88    1.000000
# co_#% of cold damage leeched as life                    95    1.000000
# co_#% of fire damage from hits taken as cold da...      95    1.000000
# co_#% of fire damage from hits taken as lightni...     101    1.000000
# co_#% of fire damage leeched as life                    86    1.000000
# co_#% of life regenerated per second                   986    1.962272
# co_#% of lightning damage from hits taken as co...     103    1.000000
# co_#% of lightning damage from hits taken as fi...     102    1.000000
# co_#% of lightning damage leeched as life               84    1.000000
# co_#% to all elemental resistances                     195   14.933333
# co_#% to all maximum resistances                        23    1.000000
# co_#% to global critical strike multiplier             929   30.327234
# co_anger has #% increased aura effect                   86   17.372093
# co_determination has #% increased aura effect           95   17.400000
# co_discipline has #% increased aura effect             101   17.465347
# co_enemies can have # additional curse                 243    1.000000
# co_gain #% of physical damage as extra damage o...     443    9.288939
# co_grace has #% increased aura effect                   80   17.437500
# co_grants level # clarity skill                        103    1.000000
# co_grants level # purity of elements skill             114    1.000000
# co_grants level # purity of fire skill                 154    1.000000
# co_grants level # purity of ice skill                   86    1.000000
# co_grants level # purity of lightning skill             98    1.000000
# co_has # socket                                        611    1.000000
# co_hatred has #% increased aura effect                 119   17.672269
# co_projectiles pierce # additional targets             765    2.000000
# co_wrath has #% increased aura effect                  114   17.885965
# corrupted                                           252015    0.128016
# date_day                                            252015    6.006476
# days_in_snapshot                                    252015    1.342976
# ex_# life gained for each enemy hit by your att...   13988    2.990921
# ex_# life gained on kill                             13554    8.421499
# ex_# life regenerated per second                     22615    6.176383
# ex_# mana gained on kill                             13116    2.780268
# ex_# mana regenerated per second                      2866    6.008863
# ex_# to accuracy rating                              37188  143.521001
# ex_# to all attributes                               34076   16.219715
# ex_# to dexterity                                    37855   26.805521
# ex_# to intelligence                                 38860   26.932630
# ex_# to maximum energy shield                        57008   21.669450
# ex_# to maximum life                                 99697   57.994594
# ex_# to maximum mana                                 57925   41.531946
# ex_# to maximum number of skeletons                    106    1.000000
# ex_# to maximum number of zombies                       84    1.000000
# ex_# to strength                                     38600   26.996503
# ex_# to total mana cost of skills                       61    7.065574
# ex_#% additional physical damage reduction              16    4.500000
# ex_#% chance to gain a power, frenzy or enduran...     246    6.105691
# ex_#% chance to recover #% of maximum mana when...       1   10.000000
# ex_#% increased area of effect                         156    9.788462
# ex_#% increased armour                               31569   10.427698
# ex_#% increased attack speed                            55    7.890909
# ex_#% increased attributes                             175    8.297143
# ex_#% increased cast speed                           15597    9.194268
# ex_#% increased chaos damage                             8   25.625000
# ex_#% increased cold damage                          13553   14.987088
# ex_#% increased damage per # dexterity                  46    1.000000
# ex_#% increased damage per # intelligence               36    1.000000
# ex_#% increased damage per # strength                   49    1.000000
# ex_#% increased elemental damage with attack sk...   12409   23.452897
# ex_#% increased evasion rating                       31107   10.367441
# ex_#% increased fire damage                          14558   15.365229
# ex_#% increased global critical strike chance        37640   24.089532
# ex_#% increased life leeched per second                  1   40.000000
# ex_#% increased lightning damage                     14770   15.376777
# ex_#% increased mana regeneration rate               24873   34.758895
# ex_#% increased maximum energy shield                36305   10.719212
# ex_#% increased maximum life                          1051    4.035205
# ex_#% increased movement speed                         132    5.189394
# ex_#% increased quantity of items found                334    6.508982
# ex_#% increased rarity of items found                32957   15.393482
# ex_#% increased spell damage                         32874   14.087698
# ex_#% of block chance applied to spells                258   33.554264
# ex_#% of cold damage leeched as life                  2126    0.400089
# ex_#% of energy shield regenerated per second          342    0.400000
# ex_#% of fire damage leeched as life                  2267    0.400269
# ex_#% of life regenerated per second                   426    0.850399
# ex_#% of lightning damage leeched as life             2455    0.400530
# ex_#% of maximum life per second to maximum lif...     101    4.045545
# ex_#% of physical attack damage leeched as life       9193    0.517863
# ex_#% of physical attack damage leeched as mana       9639    0.478099
# ex_#% of physical damage leeched as life                98    0.398878
# ex_#% reduced mana reserved                             22    4.318182
# ex_#% to all elemental resistances                   38778   10.744107
# ex_#% to chaos resistance                             7593   18.974450
# ex_#% to cold resistance                             47616   28.186177
# ex_#% to fire resistance                             48345   28.442135
# ex_#% to global critical strike multiplier           43950   24.121729
# ex_#% to lightning resistance                        49015   28.481914
# ex_#% to maximum block chance                          110    2.000000
# ex_adds # cold damage to attacks                     24932   12.769714
# ex_adds # fire damage to attacks                     25468   14.558760
# ex_adds # lightning damage to attacks                27061   17.701914
# ex_adds # physical damage to attacks                 55963    8.986679
# ex_conv_rate                                        252015   68.855436
# ex_damage penetrates #% elemental resistances          216    6.138889
# ex_gain #% of non-chaos damage as extra chaos d...     110   10.200000
# ex_gain #% of physical damage as extra cold damage     529   15.419660
# ex_gain #% of physical damage as extra fire damage     345   15.637681
# ex_gain #% of physical damage as extra lightnin...     483   15.337474
# ex_grants level # anger skill                           92   22.000000
# ex_grants level # clarity skill                        111   22.000000
# ex_grants level # determination skill                  109   22.000000
# ex_grants level # discipline skill                     141   22.000000
# ex_grants level # envy skill                             8   15.000000
# ex_grants level # grace skill                          114   22.000000
# ex_grants level # haste skill                          135   22.000000
# ex_grants level # hatred skill                         104   22.000000
# ex_grants level # vitality skill                       133   22.000000
# ex_grants level # wrath skill                           94   22.000000
# ex_items and gems have #% reduced attribute req...     172    9.744186
# ex_minions have #% increased movement speed             54   16.018519
# ex_projectiles pierce an additional target              81    1.000000
# im_# life regenerated per second                     14515    2.998643
# im_# to all attributes                               27247   13.143575
# im_# to dexterity                                    22652   25.136147
# im_# to dexterity and intelligence                   23739   20.089473
# im_# to intelligence                                 23121   25.109597
# im_# to strength                                     22384   25.118433
# im_# to strength and dexterity                       25072   20.088425
# im_# to strength and intelligence                    24344   20.098792
# im_#% increased mana regeneration rate               15430   25.280428
# im_#% increased rarity of items found                20533   16.132275
# im_#% of life regenerated per second                   716    1.435251
# influence                                             4767    1.335641
# item_level                                          252015   69.581307
# price_amount                                        252015    7.317645
# time_hours                                          252015    9.610063
#
#                                                              std        min  \
# co_# life regenerated per second                    5.965545e-01   2.000000
# co_# to all attributes                              2.005271e+00  10.000000
# co_# to dexterity                                   3.186322e+00  20.000000
# co_# to dexterity and intelligence                  2.585961e+00  16.000000
# co_# to intelligence                                3.251210e+00  20.000000
# co_# to maximum number of zombies                   0.000000e+00   1.000000
# co_# to strength                                    3.103335e+00  20.000000
# co_# to strength and dexterity                      2.545450e+00  16.000000
# co_# to strength and intelligence                   2.583300e+00  16.000000
# co_#% additional physical damage reduction          8.212443e-01   4.000000
# co_#% chance to block                               4.965517e-01   4.000000
# co_#% chance to freeze, shock and ignite            7.913656e-01   4.000000
# co_#% chance to gain a frenzy charge on kill        0.000000e+00   1.000000
# co_#% chance to gain a power charge on kill         0.000000e+00   1.000000
# co_#% chance to gain an endurance charge on kill    0.000000e+00   1.000000
# co_#% increased area of effect                      1.100968e+00   5.000000
# co_#% increased attack and cast speed               1.421228e+00   6.000000
# co_#% increased attack damage                       3.175213e+00  20.000000
# co_#% increased attack speed                        8.406828e-01   8.000000
# co_#% increased attributes                          1.419691e+00  12.000000
# co_#% increased chaos damage                        3.708550e+00  19.000000
# co_#% increased cold damage                         3.119864e+00  20.000000
# co_#% increased damage                              3.051136e+00  25.000000
# co_#% increased dexterity                           8.224758e-01   4.000000
# co_#% increased elemental damage with attack sk...  1.431706e+00  20.000000
# co_#% increased fire damage                         3.239352e+00  20.000000
# co_#% increased fish bite sensitivity               7.071068e-01  39.000000
# co_#% increased global critical strike chance       3.202496e+00  40.000000
# co_#% increased global defences                     3.221260e+00  15.000000
# co_#% increased global physical damage              3.155329e+00  20.000000
# co_#% increased intelligence                        8.193450e-01   4.000000
# co_#% increased lightning damage                    3.257552e+00  20.000000
# co_#% increased mana regeneration rate              5.265197e+00  20.000000
# co_#% increased maximum life                        1.407140e+00   8.000000
# co_#% increased maximum mana                        3.075042e+00  20.000000
# co_#% increased movement speed                      8.500604e-01   8.000000
# co_#% increased quantity of items found             1.387208e+00   6.000000
# co_#% increased rarity of items found               3.440222e+00  12.000000
# co_#% increased spell damage                        3.137583e+00  20.000000
# co_#% increased strength                            8.106220e-01   4.000000
# co_#% of block chance applied to spells             1.636560e+00  20.000000
# co_#% of cold damage from hits taken as fire da...  0.000000e+00   1.000000
# co_#% of cold damage from hits taken as lightni...  0.000000e+00   1.000000
# co_#% of cold damage leeched as life                0.000000e+00   1.000000
# co_#% of fire damage from hits taken as cold da...  0.000000e+00   1.000000
# co_#% of fire damage from hits taken as lightni...  0.000000e+00   1.000000
# co_#% of fire damage leeched as life                0.000000e+00   1.000000
# co_#% of life regenerated per second                1.490420e-01   1.200000
# co_#% of lightning damage from hits taken as co...  0.000000e+00   1.000000
# co_#% of lightning damage from hits taken as fi...  0.000000e+00   1.000000
# co_#% of lightning damage leeched as life           0.000000e+00   1.000000
# co_#% to all elemental resistances                  8.315100e-01  14.000000
# co_#% to all maximum resistances                    0.000000e+00   1.000000
# co_#% to global critical strike multiplier          3.756678e+00  24.000000
# co_anger has #% increased aura effect               1.789160e+00  15.000000
# co_determination has #% increased aura effect       1.639927e+00  15.000000
# co_discipline has #% increased aura effect          1.634407e+00  15.000000
# co_enemies can have # additional curse              0.000000e+00   1.000000
# co_gain #% of physical damage as extra damage o...  2.036442e+00   6.000000
# co_grace has #% increased aura effect               1.854476e+00  15.000000
# co_grants level # clarity skill                     0.000000e+00   1.000000
# co_grants level # purity of elements skill          0.000000e+00   1.000000
# co_grants level # purity of fire skill              0.000000e+00   1.000000
# co_grants level # purity of ice skill               0.000000e+00   1.000000
# co_grants level # purity of lightning skill         0.000000e+00   1.000000
# co_has # socket                                     0.000000e+00   1.000000
# co_hatred has #% increased aura effect              1.850832e+00  15.000000
# co_projectiles pierce # additional targets          0.000000e+00   2.000000
# co_wrath has #% increased aura effect               1.660359e+00  15.000000
# corrupted                                           3.341085e-01   0.000000
# date_day                                            1.848139e+00   4.000000
# days_in_snapshot                                    1.502195e+00   0.000000
# ex_# life gained for each enemy hit by your att...  8.198687e-01   2.000000
# ex_# life gained on kill                            3.444803e+00   3.000000
# ex_# life regenerated per second                    4.166031e+00   1.000000
# ex_# mana gained on kill                            1.730371e+00   1.000000
# ex_# mana regenerated per second                    5.844509e-01   5.000000
# ex_# to accuracy rating                             9.760695e+01   5.000000
# ex_# to all attributes                              8.363467e+00   1.000000
# ex_# to dexterity                                   1.132247e+01   8.000000
# ex_# to intelligence                                1.135751e+01   8.000000
# ex_# to maximum energy shield                       1.329072e+01   1.000000
# ex_# to maximum life                                2.357127e+01   3.000000
# ex_# to maximum mana                                1.664824e+01  15.000000
# ex_# to maximum number of skeletons                 0.000000e+00   1.000000
# ex_# to maximum number of zombies                   0.000000e+00   1.000000
# ex_# to strength                                    1.138874e+01   8.000000
# ex_# to total mana cost of skills                   1.263182e+00   4.000000
# ex_#% additional physical damage reduction          6.324555e-01   3.000000
# ex_#% chance to gain a power, frenzy or enduran...  2.290399e+00   3.000000
# ex_#% chance to recover #% of maximum mana when...           NaN  10.000000
# ex_#% increased area of effect                      2.208516e+00   7.000000
# ex_#% increased armour                              5.413149e+00   2.000000
# ex_#% increased attack speed                        2.997979e+00   4.000000
# ex_#% increased attributes                          1.983479e+00   6.000000
# ex_#% increased cast speed                          2.592151e+00   5.000000
# ex_#% increased chaos damage                        2.669270e+00  23.000000
# ex_#% increased cold damage                         6.929709e+00   3.000000
# ex_#% increased damage per # dexterity              0.000000e+00   1.000000
# ex_#% increased damage per # intelligence           0.000000e+00   1.000000
# ex_#% increased damage per # strength               0.000000e+00   1.000000
# ex_#% increased elemental damage with attack sk...  1.005806e+01   5.000000
# ex_#% increased evasion rating                      5.419786e+00   2.000000
# ex_#% increased fire damage                         6.954889e+00   3.000000
# ex_#% increased global critical strike chance       8.215262e+00  10.000000
# ex_#% increased life leeched per second                      NaN  40.000000
# ex_#% increased lightning damage                    6.950052e+00   3.000000
# ex_#% increased mana regeneration rate              1.494549e+01  10.000000
# ex_#% increased maximum energy shield               5.500770e+00   2.000000
# ex_#% increased maximum life                        8.104657e-01   3.000000
# ex_#% increased movement speed                      1.027355e+00   4.000000
# ex_#% increased quantity of items found             1.663486e+00   4.000000
# ex_#% increased rarity of items found               6.302787e+00   6.000000
# ex_#% increased spell damage                        6.397647e+00   3.000000
# ex_#% of block chance applied to spells             4.630192e+00  25.000000
# ex_#% of cold damage leeched as life                1.499934e-02   0.300000
# ex_#% of energy shield regenerated per second       2.501662e-15   0.400000
# ex_#% of fire damage leeched as life                1.222646e-02   0.300000
# ex_#% of life regenerated per second                5.954479e-01   0.400000
# ex_#% of lightning damage leeched as life           1.480809e-02   0.300000
# ex_#% of maximum life per second to maximum lif...  6.265022e-01   3.000000
# ex_#% of physical attack damage leeched as life     2.906187e-01   0.200000
# ex_#% of physical attack damage leeched as mana     2.076321e-01   0.200000
# ex_#% of physical damage leeched as life            6.040896e-02   0.300000
# ex_#% reduced mana reserved                         8.937009e-01   3.000000
# ex_#% to all elemental resistances                  4.060595e+00   3.000000
# ex_#% to chaos resistance                           7.578141e+00   5.000000
# ex_#% to cold resistance                            1.188610e+01   6.000000
# ex_#% to fire resistance                            1.181546e+01   6.000000
# ex_#% to global critical strike multiplier          8.564974e+00   8.000000
# ex_#% to lightning resistance                       1.189922e+01   6.000000
# ex_#% to maximum block chance                       0.000000e+00   2.000000
# ex_adds # cold damage to attacks                    7.157737e+00   1.500000
# ex_adds # fire damage to attacks                    8.222821e+00   1.500000
# ex_adds # lightning damage to attacks               9.308398e+00   3.000000
# ex_adds # physical damage to attacks                4.871544e+00   1.500000
# ex_conv_rate                                        9.311479e+00  60.000000
# ex_damage penetrates #% elemental resistances       1.539908e+00   4.000000
# ex_gain #% of non-chaos damage as extra chaos d...  1.890585e+00   7.000000
# ex_gain #% of physical damage as extra cold damage  3.169109e+00  10.000000
# ex_gain #% of physical damage as extra fire damage  3.240240e+00  10.000000
# ex_gain #% of physical damage as extra lightnin...  3.091949e+00  10.000000
# ex_grants level # anger skill                       0.000000e+00  22.000000
# ex_grants level # clarity skill                     0.000000e+00  22.000000
# ex_grants level # determination skill               0.000000e+00  22.000000
# ex_grants level # discipline skill                  0.000000e+00  22.000000
# ex_grants level # envy skill                        0.000000e+00  15.000000
# ex_grants level # grace skill                       0.000000e+00  22.000000
# ex_grants level # haste skill                       0.000000e+00  22.000000
# ex_grants level # hatred skill                      0.000000e+00  22.000000
# ex_grants level # vitality skill                    0.000000e+00  22.000000
# ex_grants level # wrath skill                       0.000000e+00  22.000000
# ex_items and gems have #% reduced attribute req...  3.223401e+00   5.000000
# ex_minions have #% increased movement speed         5.093432e+00   7.000000
# ex_projectiles pierce an additional target          0.000000e+00   1.000000
# im_# life regenerated per second                    5.802312e-01   2.000000
# im_# to all attributes                              1.998241e+00  10.000000
# im_# to dexterity                                   3.187905e+00  20.000000
# im_# to dexterity and intelligence                  2.573381e+00  16.000000
# im_# to intelligence                                3.175111e+00  20.000000
# im_# to strength                                    3.184276e+00  20.000000
# im_# to strength and dexterity                      2.580807e+00  16.000000
# im_# to strength and intelligence                   2.563617e+00  16.000000
# im_#% increased mana regeneration rate              4.085320e+00  20.000000
# im_#% increased rarity of items found               2.599123e+00  12.000000
# im_#% of life regenerated per second                1.192063e-01   1.200000
# influence                                           4.722636e-01   1.000000
# item_level                                          1.241546e+01   3.000000
# price_amount                                        2.293775e+02   0.062437
# time_hours                                          7.424665e+00   0.000000
#
#                                                       25%     50%      75%  \
# co_# life regenerated per second                     2.50    3.00    3.500
# co_# to all attributes                              11.00   13.00   15.000
# co_# to dexterity                                   22.00   25.00   28.000
# co_# to dexterity and intelligence                  18.00   20.00   22.000
# co_# to intelligence                                22.00   25.00   28.000
# co_# to maximum number of zombies                    1.00    1.00    1.000
# co_# to strength                                    22.00   25.00   28.000
# co_# to strength and dexterity                      18.00   20.00   22.000
# co_# to strength and intelligence                   18.00   20.00   22.000
# co_#% additional physical damage reduction           4.00    5.00    6.000
# co_#% chance to block                                4.00    5.00    5.000
# co_#% chance to freeze, shock and ignite             4.00    5.00    6.000
# co_#% chance to gain a frenzy charge on kill         1.00    1.00    1.000
# co_#% chance to gain a power charge on kill          1.00    1.00    1.000
# co_#% chance to gain an endurance charge on kill     1.00    1.00    1.000
# co_#% increased area of effect                       6.00    6.50    7.000
# co_#% increased attack and cast speed                7.00    8.00    9.000
# co_#% increased attack damage                       22.00   25.00   28.000
# co_#% increased attack speed                         8.00    9.00   10.000
# co_#% increased attributes                          13.00   14.00   15.000
# co_#% increased chaos damage                        22.00   25.00   28.000
# co_#% increased cold damage                         23.00   25.00   28.000
# co_#% increased damage                              28.00   30.00   33.000
# co_#% increased dexterity                            4.00    5.00    6.000
# co_#% increased elemental damage with attack sk...  21.00   22.00   23.000
# co_#% increased fire damage                         22.00   25.00   28.000
# co_#% increased fish bite sensitivity               39.25   39.50   39.750
# co_#% increased global critical strike chance       42.00   45.00   48.000
# co_#% increased global defences                     17.00   20.00   23.000
# co_#% increased global physical damage              23.00   26.00   28.000
# co_#% increased intelligence                         4.00    5.00    6.000
# co_#% increased lightning damage                    22.00   25.00   28.000
# co_#% increased mana regeneration rate              23.00   25.00   28.000
# co_#% increased maximum life                         9.00   10.00   11.000
# co_#% increased maximum mana                        23.00   25.00   28.000
# co_#% increased movement speed                       8.00    9.00   10.000
# co_#% increased quantity of items found              7.00    9.00   10.000
# co_#% increased rarity of items found               14.00   16.00   19.000
# co_#% increased spell damage                        23.00   25.00   28.000
# co_#% increased strength                             4.00    5.00    6.000
# co_#% of block chance applied to spells             21.00   22.00   24.000
# co_#% of cold damage from hits taken as fire da...   1.00    1.00    1.000
# co_#% of cold damage from hits taken as lightni...   1.00    1.00    1.000
# co_#% of cold damage leeched as life                 1.00    1.00    1.000
# co_#% of fire damage from hits taken as cold da...   1.00    1.00    1.000
# co_#% of fire damage from hits taken as lightni...   1.00    1.00    1.000
# co_#% of fire damage leeched as life                 1.00    1.00    1.000
# co_#% of life regenerated per second                 2.00    2.00    2.000
# co_#% of lightning damage from hits taken as co...   1.00    1.00    1.000
# co_#% of lightning damage from hits taken as fi...   1.00    1.00    1.000
# co_#% of lightning damage leeched as life            1.00    1.00    1.000
# co_#% to all elemental resistances                  14.00   15.00   16.000
# co_#% to all maximum resistances                     1.00    1.00    1.000
# co_#% to global critical strike multiplier          27.00   30.00   34.000
# co_anger has #% increased aura effect               16.00   17.00   19.000
# co_determination has #% increased aura effect       16.00   17.00   19.000
# co_discipline has #% increased aura effect          16.00   17.00   19.000
# co_enemies can have # additional curse               1.00    1.00    1.000
# co_gain #% of physical damage as extra damage o...   7.00   10.00   11.000
# co_grace has #% increased aura effect               16.00   17.00   19.000
# co_grants level # clarity skill                      1.00    1.00    1.000
# co_grants level # purity of elements skill           1.00    1.00    1.000
# co_grants level # purity of fire skill               1.00    1.00    1.000
# co_grants level # purity of ice skill                1.00    1.00    1.000
# co_grants level # purity of lightning skill          1.00    1.00    1.000
# co_has # socket                                      1.00    1.00    1.000
# co_hatred has #% increased aura effect              16.00   18.00   19.500
# co_projectiles pierce # additional targets           2.00    2.00    2.000
# co_wrath has #% increased aura effect               17.00   18.00   19.000
# corrupted                                            0.00    0.00    0.000
# date_day                                             4.00    6.00    7.000
# days_in_snapshot                                     0.00    1.00    2.000
# ex_# life gained for each enemy hit by your att...   2.00    3.00    4.000
# ex_# life gained on kill                             5.00    8.00   11.000
# ex_# life regenerated per second                     2.40    5.30    9.400
# ex_# mana gained on kill                             1.00    2.00    4.000
# ex_# mana regenerated per second                     5.50    6.00    6.500
# ex_# to accuracy rating                             63.00  133.00  210.000
# ex_# to all attributes                               9.00   17.00   23.000
# ex_# to dexterity                                   17.00   26.00   36.000
# ex_# to intelligence                                17.00   27.00   36.000
# ex_# to maximum energy shield                       11.00   20.00   32.000
# ex_# to maximum life                                42.00   64.00   77.000
# ex_# to maximum mana                                28.00   40.00   54.000
# ex_# to maximum number of skeletons                  1.00    1.00    1.000
# ex_# to maximum number of zombies                    1.00    1.00    1.000
# ex_# to strength                                    17.00   27.00   36.000
# ex_# to total mana cost of skills                    7.00    8.00    8.000
# ex_#% additional physical damage reduction           4.00    5.00    5.000
# ex_#% chance to gain a power, frenzy or enduran...   4.00    6.00    8.000
# ex_#% chance to recover #% of maximum mana when...  10.00   10.00   10.000
# ex_#% increased area of effect                       8.00    9.00   11.000
# ex_#% increased armour                               6.00   10.00   15.000
# ex_#% increased attack speed                         5.50    7.00   10.500
# ex_#% increased attributes                           7.00    8.00   10.000
# ex_#% increased cast speed                           7.00    9.00   11.000
# ex_#% increased chaos damage                        23.75   25.00   26.750
# ex_#% increased cold damage                          9.00   15.00   21.000
# ex_#% increased damage per # dexterity               1.00    1.00    1.000
# ex_#% increased damage per # intelligence            1.00    1.00    1.000
# ex_#% increased damage per # strength                1.00    1.00    1.000
# ex_#% increased elemental damage with attack sk...  15.00   25.00   32.000
# ex_#% increased evasion rating                       6.00   10.00   15.000
# ex_#% increased fire damage                          9.00   16.00   22.000
# ex_#% increased global critical strike chance       17.00   24.00   31.000
# ex_#% increased life leeched per second             40.00   40.00   40.000
# ex_#% increased lightning damage                    10.00   16.00   21.000
# ex_#% increased mana regeneration rate              22.00   34.00   47.000
# ex_#% increased maximum energy shield                6.00   10.00   15.000
# ex_#% increased maximum life                         3.00    4.00    5.000
# ex_#% increased movement speed                       4.00    5.00    6.000
# ex_#% increased quantity of items found              5.00    6.00    7.000
# ex_#% increased rarity of items found               11.00   14.00   19.000
# ex_#% increased spell damage                         9.00   14.00   20.000
# ex_#% of block chance applied to spells             30.00   34.00   38.000
# ex_#% of cold damage leeched as life                 0.40    0.40    0.400
# ex_#% of energy shield regenerated per second        0.40    0.40    0.400
# ex_#% of fire damage leeched as life                 0.40    0.40    0.400
# ex_#% of life regenerated per second                 0.40    0.40    1.395
# ex_#% of lightning damage leeched as life            0.40    0.40    0.400
# ex_#% of maximum life per second to maximum lif...   3.40    4.10    4.600
# ex_#% of physical attack damage leeched as life      0.29    0.37    0.720
# ex_#% of physical attack damage leeched as mana      0.29    0.38    0.690
# ex_#% of physical damage leeched as life             0.35    0.40    0.450
# ex_#% reduced mana reserved                          3.25    5.00    5.000
# ex_#% to all elemental resistances                   7.00   11.00   15.000
# ex_#% to chaos resistance                           13.00   19.00   25.000
# ex_#% to cold resistance                            18.00   29.00   39.000
# ex_#% to fire resistance                            19.00   29.00   39.000
# ex_#% to global critical strike multiplier          17.00   25.00   31.000
# ex_#% to lightning resistance                       19.00   29.00   39.000
# ex_#% to maximum block chance                        2.00    2.00    2.000
# ex_adds # cold damage to attacks                     7.50   12.00   18.500
# ex_adds # fire damage to attacks                     8.50   14.50   21.000
# ex_adds # lightning damage to attacks               11.50   17.50   25.500
# ex_adds # physical damage to attacks                 5.00    8.50   12.500
# ex_conv_rate                                        60.00   64.00   77.000
# ex_damage penetrates #% elemental resistances        5.00    6.00    7.000
# ex_gain #% of non-chaos damage as extra chaos d...   9.00   10.00   12.000
# ex_gain #% of physical damage as extra cold damage  13.00   15.00   18.000
# ex_gain #% of physical damage as extra fire damage  13.00   16.00   18.000
# ex_gain #% of physical damage as extra lightnin...  13.00   15.00   18.000
# ex_grants level # anger skill                       22.00   22.00   22.000
# ex_grants level # clarity skill                     22.00   22.00   22.000
# ex_grants level # determination skill               22.00   22.00   22.000
# ex_grants level # discipline skill                  22.00   22.00   22.000
# ex_grants level # envy skill                        15.00   15.00   15.000
# ex_grants level # grace skill                       22.00   22.00   22.000
# ex_grants level # haste skill                       22.00   22.00   22.000
# ex_grants level # hatred skill                      22.00   22.00   22.000
# ex_grants level # vitality skill                    22.00   22.00   22.000
# ex_grants level # wrath skill                       22.00   22.00   22.000
# ex_items and gems have #% reduced attribute req...   7.00    9.00   13.000
# ex_minions have #% increased movement speed         12.00   15.00   20.000
# ex_projectiles pierce an additional target           1.00    1.00    1.000
# im_# life regenerated per second                     2.50    3.00    3.500
# im_# to all attributes                              11.00   13.00   15.000
# im_# to dexterity                                   22.00   25.00   28.000
# im_# to dexterity and intelligence                  18.00   20.00   22.000
# im_# to intelligence                                22.00   25.00   28.000
# im_# to strength                                    22.00   25.00   28.000
# im_# to strength and dexterity                      18.00   20.00   22.000
# im_# to strength and intelligence                   18.00   20.00   22.000
# im_#% increased mana regeneration rate              22.00   25.00   28.000
# im_#% increased rarity of items found               14.00   16.00   18.000
# im_#% of life regenerated per second                 1.33    1.45    1.550
# influence                                            1.00    1.00    2.000
# item_level                                          69.00   73.00   76.000
# price_amount                                         1.00    2.00    5.000
# time_hours                                           3.00    8.00   16.000
#
#                                                             max  median  \
# co_# life regenerated per second                        4.00000    3.00
# co_# to all attributes                                 16.00000   13.00
# co_# to dexterity                                      30.00000   25.00
# co_# to dexterity and intelligence                     24.00000   20.00
# co_# to intelligence                                   30.00000   25.00
# co_# to maximum number of zombies                       1.00000    1.00
# co_# to strength                                       30.00000   25.00
# co_# to strength and dexterity                         24.00000   20.00
# co_# to strength and intelligence                      24.00000   20.00
# co_#% additional physical damage reduction              6.00000    5.00
# co_#% chance to block                                   5.00000    5.00
# co_#% chance to freeze, shock and ignite                6.00000    5.00
# co_#% chance to gain a frenzy charge on kill            1.00000    1.00
# co_#% chance to gain a power charge on kill             1.00000    1.00
# co_#% chance to gain an endurance charge on kill        1.00000    1.00
# co_#% increased area of effect                          8.00000    6.50
# co_#% increased attack and cast speed                  10.00000    8.00
# co_#% increased attack damage                          30.00000   25.00
# co_#% increased attack speed                           10.00000    9.00
# co_#% increased attributes                             16.00000   14.00
# co_#% increased chaos damage                           31.00000   25.00
# co_#% increased cold damage                            30.00000   25.00
# co_#% increased damage                                 35.00000   30.00
# co_#% increased dexterity                               6.00000    5.00
# co_#% increased elemental damage with attack sk...     24.00000   22.00
# co_#% increased fire damage                            30.00000   25.00
# co_#% increased fish bite sensitivity                  40.00000   39.50
# co_#% increased global critical strike chance          50.00000   45.00
# co_#% increased global defences                        25.00000   20.00
# co_#% increased global physical damage                 30.00000   26.00
# co_#% increased intelligence                            6.00000    5.00
# co_#% increased lightning damage                       30.00000   25.00
# co_#% increased mana regeneration rate                 56.00000   25.00
# co_#% increased maximum life                           12.00000   10.00
# co_#% increased maximum mana                           30.00000   25.00
# co_#% increased movement speed                         10.00000    9.00
# co_#% increased quantity of items found                10.00000    9.00
# co_#% increased rarity of items found                  30.00000   16.00
# co_#% increased spell damage                           30.00000   25.00
# co_#% increased strength                                9.00000    5.00
# co_#% of block chance applied to spells                25.00000   22.00
# co_#% of cold damage from hits taken as fire da...      1.00000    1.00
# co_#% of cold damage from hits taken as lightni...      1.00000    1.00
# co_#% of cold damage leeched as life                    1.00000    1.00
# co_#% of fire damage from hits taken as cold da...      1.00000    1.00
# co_#% of fire damage from hits taken as lightni...      1.00000    1.00
# co_#% of fire damage leeched as life                    1.00000    1.00
# co_#% of life regenerated per second                    2.00000    2.00
# co_#% of lightning damage from hits taken as co...      1.00000    1.00
# co_#% of lightning damage from hits taken as fi...      1.00000    1.00
# co_#% of lightning damage leeched as life               1.00000    1.00
# co_#% to all elemental resistances                     16.00000   15.00
# co_#% to all maximum resistances                        1.00000    1.00
# co_#% to global critical strike multiplier             36.00000   30.00
# co_anger has #% increased aura effect                  20.00000   17.00
# co_determination has #% increased aura effect          20.00000   17.00
# co_discipline has #% increased aura effect             20.00000   17.00
# co_enemies can have # additional curse                  1.00000    1.00
# co_gain #% of physical damage as extra damage o...     12.00000   10.00
# co_grace has #% increased aura effect                  20.00000   17.00
# co_grants level # clarity skill                         1.00000    1.00
# co_grants level # purity of elements skill              1.00000    1.00
# co_grants level # purity of fire skill                  1.00000    1.00
# co_grants level # purity of ice skill                   1.00000    1.00
# co_grants level # purity of lightning skill             1.00000    1.00
# co_has # socket                                         1.00000    1.00
# co_hatred has #% increased aura effect                 20.00000   18.00
# co_projectiles pierce # additional targets              2.00000    2.00
# co_wrath has #% increased aura effect                  20.00000   18.00
# corrupted                                               1.00000    0.00
# date_day                                               10.00000    6.00
# days_in_snapshot                                        6.00000    1.00
# ex_# life gained for each enemy hit by your att...      4.00000    3.00
# ex_# life gained on kill                               14.00000    8.00
# ex_# life regenerated per second                       20.00000    5.30
# ex_# mana gained on kill                                6.00000    2.00
# ex_# mana regenerated per second                        7.00000    6.00
# ex_# to accuracy rating                               400.00000  133.00
# ex_# to all attributes                                 35.00000   17.00
# ex_# to dexterity                                      55.00000   26.00
# ex_# to intelligence                                   55.00000   27.00
# ex_# to maximum energy shield                          51.00000   20.00
# ex_# to maximum life                                   89.00000   64.00
# ex_# to maximum mana                                   78.00000   40.00
# ex_# to maximum number of skeletons                     1.00000    1.00
# ex_# to maximum number of zombies                       1.00000    1.00
# ex_# to strength                                       55.00000   27.00
# ex_# to total mana cost of skills                       8.00000    8.00
# ex_#% additional physical damage reduction              5.00000    5.00
# ex_#% chance to gain a power, frenzy or enduran...     10.00000    6.00
# ex_#% chance to recover #% of maximum mana when...     10.00000   10.00
# ex_#% increased area of effect                         15.00000    9.00
# ex_#% increased armour                                 22.00000   10.00
# ex_#% increased attack speed                           13.00000    7.00
# ex_#% increased attributes                             12.00000    8.00
# ex_#% increased cast speed                             13.00000    9.00
# ex_#% increased chaos damage                           30.00000   25.00
# ex_#% increased cold damage                            30.00000   15.00
# ex_#% increased damage per # dexterity                  1.00000    1.00
# ex_#% increased damage per # intelligence               1.00000    1.00
# ex_#% increased damage per # strength                   1.00000    1.00
# ex_#% increased elemental damage with attack sk...     50.00000   25.00
# ex_#% increased evasion rating                         22.00000   10.00
# ex_#% increased fire damage                            30.00000   16.00
# ex_#% increased global critical strike chance          38.00000   24.00
# ex_#% increased life leeched per second                40.00000   40.00
# ex_#% increased lightning damage                       30.00000   16.00
# ex_#% increased mana regeneration rate                 69.00000   34.00
# ex_#% increased maximum energy shield                  29.00000   10.00
# ex_#% increased maximum life                            5.00000    4.00
# ex_#% increased movement speed                          8.00000    5.00
# ex_#% increased quantity of items found                10.00000    6.00
# ...
# ex_#% of physical attack damage leeched as mana                0.039
# ex_#% of physical damage leeched as life                      -0.059
# ex_#% reduced mana reserved                                    0.005
# ex_#% to all elemental resistances                             0.197
# ex_#% to chaos resistance                                      0.177
# ex_#% to cold resistance                                       0.206
# ex_#% to fire resistance                                       0.212
# ex_#% to global critical strike multiplier                     0.280
# ex_#% to lightning resistance                                  0.218
# ex_#% to maximum block chance                                    NaN
# ex_adds # cold damage to attacks                               0.118
# ex_adds # fire damage to attacks                               0.125
# ex_adds # lightning damage to attacks                          0.156
# ex_adds # physical damage to attacks                           0.205
# ex_conv_rate                                                   0.121
# ex_damage penetrates #% elemental resistances                  0.342
# ex_gain #% of non-chaos damage as extra chaos d...             0.272
# ex_gain #% of physical damage as extra cold damage             0.249
# ex_gain #% of physical damage as extra fire damage             0.149
# ex_gain #% of physical damage as extra lightnin...             0.309
# ex_grants level # anger skill                                    NaN
# ex_grants level # clarity skill                                  NaN
# ex_grants level # determination skill                            NaN
# ex_grants level # discipline skill                               NaN
# ex_grants level # envy skill                                     NaN
# ex_grants level # grace skill                                    NaN
# ex_grants level # haste skill                                    NaN
# ex_grants level # hatred skill                                   NaN
# ex_grants level # vitality skill                                 NaN
# ex_grants level # wrath skill                                    NaN
# ex_items and gems have #% reduced attribute req...             0.244
# ex_minions have #% increased movement speed                    0.662
# ex_projectiles pierce an additional target                       NaN
# im_# life regenerated per second                              -0.013
# im_# to all attributes                                         0.028
# im_# to dexterity                                              0.013
# im_# to dexterity and intelligence                             0.015
# im_# to intelligence                                           0.025
# im_# to strength                                               0.021
# im_# to strength and dexterity                                 0.014
# im_# to strength and intelligence                              0.022
# im_#% increased mana regeneration rate                         0.011
# im_#% increased rarity of items found                          0.008
# im_#% of life regenerated per second                           0.277
# influence                                                     -0.100
# item_level                                                     0.359
# price_amount                                                   1.000
# time_hours                                                     0.070
#
#                                                     percentage_to_rows
# co_# life regenerated per second                              0.417435
# co_# to all attributes                                        0.446402
# co_# to dexterity                                             0.367438
# co_# to dexterity and intelligence                            0.376565
# co_# to intelligence                                          0.424578
# co_# to maximum number of zombies                             0.316251
# co_# to strength                                              0.398389
# co_# to strength and dexterity                                0.381723
# co_# to strength and intelligence                             0.417832
# co_#% additional physical damage reduction                    0.115073
# co_#% chance to block                                         0.038490
# co_#% chance to freeze, shock and ignite                      0.208321
# co_#% chance to gain a frenzy charge on kill                  0.056743
# co_#% chance to gain a power charge on kill                   0.049203
# co_#% chance to gain an endurance charge on kill              0.058727
# co_#% increased area of effect                                0.134119
# co_#% increased attack and cast speed                         0.320219
# co_#% increased attack damage                                 0.323393
# co_#% increased attack speed                                  0.058727
# co_#% increased attributes                                    0.172212
# co_#% increased chaos damage                                  0.286888
# co_#% increased cold damage                                   0.307125
# co_#% increased damage                                        0.190068
# co_#% increased dexterity                                     0.105946
# co_#% increased elemental damage with attack sk...            0.071424
# co_#% increased fire damage                                   0.307918
# co_#% increased fish bite sensitivity                         0.000794
# co_#% increased global critical strike chance                 0.359502
# co_#% increased global defences                               0.259508
# co_#% increased global physical damage                        0.333710
# co_#% increased intelligence                                  0.111104
# co_#% increased lightning damage                              0.340456
# co_#% increased mana regeneration rate                        0.488463
# co_#% increased maximum life                                  0.355534
# co_#% increased maximum mana                                  0.258715
# co_#% increased movement speed                                0.028967
# co_#% increased quantity of items found                       0.649168
# co_#% increased rarity of items found                         0.450370
# co_#% increased spell damage                                  0.390850
# co_#% increased strength                                      0.108724
# co_#% of block chance applied to spells                       0.046823
# co_#% of cold damage from hits taken as fire da...            0.034919
# co_#% of cold damage from hits taken as lightni...            0.034919
# co_#% of cold damage leeched as life                          0.037696
# co_#% of fire damage from hits taken as cold da...            0.037696
# co_#% of fire damage from hits taken as lightni...            0.040077
# co_#% of fire damage leeched as life                          0.034125
# co_#% of life regenerated per second                          0.391247
# co_#% of lightning damage from hits taken as co...            0.040871
# co_#% of lightning damage from hits taken as fi...            0.040474
# co_#% of lightning damage leeched as life                     0.033331
# co_#% to all elemental resistances                            0.077376
# co_#% to all maximum resistances                              0.009126
# co_#% to global critical strike multiplier                    0.368629
# co_anger has #% increased aura effect                         0.034125
# co_determination has #% increased aura effect                 0.037696
# co_discipline has #% increased aura effect                    0.040077
# co_enemies can have # additional curse                        0.096423
# co_gain #% of physical damage as extra damage o...            0.175783
# co_grace has #% increased aura effect                         0.031744
# co_grants level # clarity skill                               0.040871
# co_grants level # purity of elements skill                    0.045235
# co_grants level # purity of fire skill                        0.061107
# co_grants level # purity of ice skill                         0.034125
# co_grants level # purity of lightning skill                   0.038887
# co_has # socket                                               0.242446
# co_hatred has #% increased aura effect                        0.047219
# co_projectiles pierce # additional targets                    0.303553
# co_wrath has #% increased aura effect                         0.045235
# corrupted                                                   100.000000
# date_day                                                    100.000000
# days_in_snapshot                                            100.000000
# ex_# life gained for each enemy hit by your att...            5.550463
# ex_# life gained on kill                                      5.378251
# ex_# life regenerated per second                              8.973672
# ex_# mana gained on kill                                      5.204452
# ex_# mana regenerated per second                              1.137234
# ex_# to accuracy rating                                      14.756265
# ex_# to all attributes                                       13.521417
# ex_# to dexterity                                            15.020931
# ex_# to intelligence                                         15.419717
# ex_# to maximum energy shield                                22.620876
# ex_# to maximum life                                         39.559947
# ex_# to maximum mana                                         22.984743
# ex_# to maximum number of skeletons                           0.042061
# ex_# to maximum number of zombies                             0.033331
# ex_# to strength                                             15.316549
# ex_# to total mana cost of skills                             0.024205
# ex_#% additional physical damage reduction                    0.006349
# ex_#% chance to gain a power, frenzy or enduran...            0.097613
# ex_#% chance to recover #% of maximum mana when...            0.000397
# ex_#% increased area of effect                                0.061901
# ex_#% increased armour                                       12.526635
# ex_#% increased attack speed                                  0.021824
# ex_#% increased attributes                                    0.069440
# ex_#% increased cast speed                                    6.188917
# ex_#% increased chaos damage                                  0.003174
# ex_#% increased cold damage                                   5.377854
# ex_#% increased damage per # dexterity                        0.018253
# ex_#% increased damage per # intelligence                     0.014285
# ex_#% increased damage per # strength                         0.019443
# ex_#% increased elemental damage with attack sk...            4.923913
# ex_#% increased evasion rating                               12.343313
# ex_#% increased fire damage                                   5.776640
# ex_#% increased global critical strike chance                14.935619
# ex_#% increased life leeched per second                       0.000397
# ex_#% increased lightning damage                              5.860762
# ex_#% increased mana regeneration rate                        9.869651
# ex_#% increased maximum energy shield                        14.405889
# ex_#% increased maximum life                                  0.417039
# ex_#% increased movement speed                                0.052378
# ex_#% increased quantity of items found                       0.132532
# ex_#% increased rarity of items found                        13.077396
# ex_#% increased spell damage                                 13.044462
# ex_#% of block chance applied to spells                       0.102375
# ex_#% of cold damage leeched as life                          0.843601
# ex_#% of energy shield regenerated per second                 0.135706
# ex_#% of fire damage leeched as life                          0.899550
# ex_#% of life regenerated per second                          0.169038
# ex_#% of lightning damage leeched as life                     0.974148
# ex_#% of maximum life per second to maximum lif...            0.040077
# ex_#% of physical attack damage leeched as life               3.647799
# ex_#% of physical attack damage leeched as mana               3.824772
# ex_#% of physical damage leeched as life                      0.038887
# ex_#% reduced mana reserved                                   0.008730
# ex_#% to all elemental resistances                           15.387179
# ex_#% to chaos resistance                                     3.012916
# ex_#% to cold resistance                                     18.894113
# ex_#% to fire resistance                                     19.183382
# ex_#% to global critical strike multiplier                   17.439438
# ex_#% to lightning resistance                                19.449239
# ex_#% to maximum block chance                                 0.043648
# ex_adds # cold damage to attacks                              9.893062
# ex_adds # fire damage to attacks                             10.105748
# ex_adds # lightning damage to attacks                        10.737853
# ex_adds # physical damage to attacks                         22.206218
# ex_conv_rate                                                100.000000
# ex_damage penetrates #% elemental resistances                 0.085709
# ex_gain #% of non-chaos damage as extra chaos d...            0.043648
# ex_gain #% of physical damage as extra cold damage            0.209908
# ex_gain #% of physical damage as extra fire damage            0.136897
# ex_gain #% of physical damage as extra lightnin...            0.191655
# ex_grants level # anger skill                                 0.036506
# ex_grants level # clarity skill                               0.044045
# ex_grants level # determination skill                         0.043251
# ex_grants level # discipline skill                            0.055949
# ex_grants level # envy skill                                  0.003174
# ex_grants level # grace skill                                 0.045235
# ex_grants level # haste skill                                 0.053568
# ex_grants level # hatred skill                                0.041267
# ex_grants level # vitality skill                              0.052775
# ex_grants level # wrath skill                                 0.037299
# ex_items and gems have #% reduced attribute req...            0.068250
# ex_minions have #% increased movement speed                   0.021427
# ex_projectiles pierce an additional target                    0.032141
# im_# life regenerated per second                              5.759578
# im_# to all attributes                                       10.811658
# im_# to dexterity                                             8.988354
# im_# to dexterity and intelligence                            9.419677
# im_# to intelligence                                          9.174454
# im_# to strength                                              8.882011
# im_# to strength and dexterity                                9.948614
# im_# to strength and intelligence                             9.659742
# im_#% increased mana regeneration rate                        6.122651
# im_#% increased rarity of items found                         8.147531
# im_#% of life regenerated per second                          0.284110
# influence                                                     1.891554
# item_level                                                  100.000000
# price_amount                                                100.000000
# time_hours                                                  100.000000

# %%
column_statistics_o.to_csv('astatistics_with_outliers.csv',sep='^')

# %% [markdown]
# ## Without outliers

# %%
proc_category_df_zscore_1 = remove_outliers_zscore(proc_category_df,threshold=1)
proc_category_df_zscore_2 = remove_outliers_zscore(proc_category_df,threshold=2)
proc_category_df_zscore_3 = remove_outliers_zscore(proc_category_df,threshold=3)

proc_category_df_IQR_70 = remove_outliers_IQR(proc_category_df,high_quantile=0.7)
proc_category_df_IQR_80 = remove_outliers_IQR(proc_category_df,high_quantile=0.8)
proc_category_df_IQR_90 = remove_outliers_IQR(proc_category_df,high_quantile=0.9)

# %% [markdown]
# ### Zscore , threshold = 1

# %%
corr_kendall_zscore_1 = compute_corr(proc_category_df_zscore_1,method='kendall')
corr_spear_zscore_1 = compute_corr(proc_category_df_zscore_1,method='spearman')
corr_pears_zscore_1 = compute_corr(proc_category_df_zscore_1,method='pearson')

column_statistics_zscore_1 = proc_category_df_zscore_1.describe().transpose()
column_statistics_zscore_1['median'] = proc_category_df_zscore_1.median()
column_statistics_zscore_1['variance'] = proc_category_df_zscore_1.var()
column_statistics_zscore_1['count'] = (proc_category_df_zscore_1.notna()).sum()
column_statistics_zscore_1['corr_kend_price'] = corr_kendall_zscore_1['price_amount'].round(3)
column_statistics_zscore_1['corr_pears_price'] =corr_pears_zscore_1['price_amount'].round(3)
column_statistics_zscore_1['corr_spear_price'] =corr_spear_zscore_1['price_amount'].round(3)
column_statistics_zscore_1['percentage_to_rows'] = (proc_category_df_zscore_1.notna()).sum()/len(proc_category_df_zscore_1)*100
column_statistics_zscore_1.to_csv('C:/Users/Digi/Desktop/rares/amulet_stats_zscore_1.csv',sep='^')

# %% [markdown]
# ### Zscore , threshold = 2

# %%
corr_kendall_zscore_2 = compute_corr(proc_category_df_zscore_2,method='kendall')
corr_spear_zscore_2 = compute_corr(proc_category_df_zscore_2,method='spearman')
corr_pears_zscore_2 = compute_corr(proc_category_df_zscore_2,method='pearson')

column_statistics_zscore_2 = proc_category_df_zscore_2.describe().transpose()
column_statistics_zscore_2['median'] = proc_category_df_zscore_2.median()
column_statistics_zscore_2['variance'] = proc_category_df_zscore_2.var()
column_statistics_zscore_2['count'] = (proc_category_df_zscore_2.notna()).sum()
column_statistics_zscore_2['corr_kend_price'] = corr_kendall_zscore_2['price_amount'].round(3)
column_statistics_zscore_2['corr_pears_price'] =corr_pears_zscore_2['price_amount'].round(3)
column_statistics_zscore_2['corr_spear_price'] =corr_spear_zscore_2['price_amount'].round(3)
column_statistics_zscore_2['percentage_to_rows'] = (proc_category_df_zscore_2.notna()).sum()/len(proc_category_df_zscore_2)*100
column_statistics_zscore_2.to_csv('amulet_stats_zscore_2.csv',sep='^')

# %% [markdown]
# ### Zscore , threshold = 3

# %%
corr_kendall_zscore_3 = compute_corr(proc_category_df_zscore_3,method='kendall')
corr_spear_zscore_3 = compute_corr(proc_category_df_zscore_3,method='spearman')
corr_pears_zscore_3 = compute_corr(proc_category_df_zscore_3,method='pearson')

column_statistics_zscore_3 = proc_category_df_zscore_3.describe().transpose()
column_statistics_zscore_3['median'] = proc_category_df_zscore_3.median()
column_statistics_zscore_3['variance'] = proc_category_df_zscore_3.var()
column_statistics_zscore_3['count'] = (proc_category_df_zscore_3.notna()).sum()
column_statistics_zscore_3['corr_kend_price'] = corr_kendall_zscore_3['price_amount'].round(3)
column_statistics_zscore_3['corr_pears_price'] =corr_pears_zscore_3['price_amount'].round(3)
column_statistics_zscore_3['corr_spear_price'] =corr_spear_zscore_3['price_amount'].round(3)
column_statistics_zscore_3['percentage_to_rows'] = (proc_category_df_zscore_3.notna()).sum()/len(proc_category_df_zscore_3)*100
column_statistics_zscore_3.to_csv('amulet_stats_zscore_3.csv',sep='^')

# %% [markdown]
# ### IQR , high_quantile = 0.7

# %%
corr_kendall_IQR_70 = compute_corr(proc_category_df_IQR_70,method='kendall')
corr_spear_IQR_70 = compute_corr(proc_category_df_IQR_70,method='spearman')
corr_pears_IQR_70 = compute_corr(proc_category_df_IQR_70,method='pearson')

column_statistics_IQR_70 = proc_category_df_IQR_70.describe().transpose()
column_statistics_IQR_70['median'] = proc_category_df_IQR_70.median()
column_statistics_IQR_70['variance'] = proc_category_df_IQR_70.var()
column_statistics_IQR_70['count'] = (proc_category_df_IQR_70.notna()).sum()
column_statistics_IQR_70['corr_kend_price'] = corr_kendall_IQR_70['price_amount'].round(3)
column_statistics_IQR_70['corr_pears_price'] =corr_pears_IQR_70['price_amount'].round(3)
column_statistics_IQR_70['corr_spear_price'] =corr_spear_IQR_70['price_amount'].round(3)
column_statistics_IQR_70['percentage_to_rows'] = (proc_category_df_IQR_70.notna()).sum()/len(proc_category_df_IQR_70)*100
column_statistics_IQR_70.to_csv('amulet_stats_IQR_70.csv',sep='^')

# %% [markdown]
# ### IQR , high_quantile = 0.8

# %%
corr_kendall_IQR_80 = compute_corr(proc_category_df_IQR_80,method='kendall')
corr_spear_IQR_80 = compute_corr(proc_category_df_IQR_80,method='spearman')
corr_pears_IQR_80 = compute_corr(proc_category_df_IQR_80,method='pearson')

column_statistics_IQR_80 = proc_category_df_IQR_80.describe().transpose()
column_statistics_IQR_80['median'] = proc_category_df_IQR_80.median()
column_statistics_IQR_80['variance'] = proc_category_df_IQR_80.var()
column_statistics_IQR_80['count'] = (proc_category_df_IQR_80.notna()).sum()
column_statistics_IQR_80['corr_kend_price'] = corr_kendall_IQR_80['price_amount'].round(3)
column_statistics_IQR_80['corr_pears_price'] =corr_pears_IQR_80['price_amount'].round(3)
column_statistics_IQR_80['corr_spear_price'] =corr_spear_IQR_80['price_amount'].round(3)
column_statistics_IQR_80['percentage_to_rows'] = (proc_category_df_IQR_80.notna()).sum()/len(proc_category_df_IQR_80)*100
column_statistics_IQR_80.to_csv('amulet_stats_IQR_80.csv',sep='^')

# %% [markdown]
# ### IQR , high_quantile = 0.9

# %%
corr_kendall_IQR_90 = compute_corr(proc_category_df_IQR_90,method='kendall')
corr_spear_IQR_90 = compute_corr(proc_category_df_IQR_90,method='spearman')
corr_pears_IQR_90 = compute_corr(proc_category_df_IQR_90,method='pearson')

column_statistics_IQR_90 = proc_category_df_IQR_90.describe().transpose()
column_statistics_IQR_90['median'] = proc_category_df_IQR_90.median()
column_statistics_IQR_90['variance'] = proc_category_df_IQR_90.var()
column_statistics_IQR_90['count'] = (proc_category_df_IQR_90.notna()).sum()
column_statistics_IQR_90['corr_kend_price'] = corr_kendall_IQR_90['price_amount'].round(3)
column_statistics_IQR_90['corr_pears_price'] =corr_pears_IQR_90['price_amount'].round(3)
column_statistics_IQR_90['corr_spear_price'] =corr_spear_IQR_90['price_amount'].round(3)
column_statistics_IQR_90['percentage_to_rows'] = (proc_category_df_IQR_90.notna()).sum()/len(proc_category_df_IQR_90)*100
column_statistics_IQR_90.to_csv('amulet_stats_IQR_90.csv',sep='^')

# %% [markdown]
# # Comparing and filtering

# %%
directory = "C:/Users/Digi/Desktop/rares/"
files_to_process = [x for x in glob.glob(directory+''+'*.csv')]

dfs_per_category = {}

for f in files_to_process:
    base_fname = pathlib.PurePath(f).name
    category = base_fname.split('_')[0]
    type_of_csv = base_fname.split('_',maxsplit=1)[1]
    if category not in dfs_per_category:
        dfs_per_category[category] = {}
        
    df = pd.read_csv(f,delimiter='^').set_index('Unnamed: 0')
    
    if type_of_csv not in dfs_per_category[category]:
        dfs_per_category[category][type_of_csv] = df

# %%
columns = ['item_category','stats_o.csv','stats_zscore_1.csv','stats_zscore_2.csv','stats_zscore_3.csv','stats_IQR_70.csv','stats_IQR_80.csv','stats_IQR_90.csv']

compare_categories_df =  pd.DataFrame(columns=columns)

for key_item_category, type_of_df in dfs_per_category.items():
    
    category_dict = {'item_category':key_item_category}
    
    for df_category,df in type_of_df.items():
        category_dict[df_category] =df.loc['price_amount','max']
    compare_categories_df = compare_categories_df.append(category_dict,ignore_index=True)

compare_categories_df = compare_categories_df.set_index('item_category')

# %%
compare_categories_df.columns = ['max_price_outliers','max_price_zscore_1','max_price_zscore_2','max_price_zscore_3','max_price_IQR_70','max_price_IQR_80','max_price_IQR_90']

# %%
compare_categories_df.astype(int)
# Out:
#                max_price_outliers  max_price_zscore_1  max_price_zscore_2  \
# item_category
# amulet                      85547                 231                 462
# belt                      4050000                4830                4830
# boots                     6249999                8100                8100
# bow                       7699923               34500               34500
# chest                       88923                 360                 728
# claw                       847982                3311                8395
# dagger                      13498                  90                 169
# gloves                      99999                 364                 719
# helmet                       6400                  60                 114
# jewels                   15961149                6000                6000
# oneaxe                      81000                 648                1300
# onemace                     77000                 364                 693
# onesword                    28240                 202                 390
# quiver                       2430                  36                  65
# ring                  -2147483648              123123              123123
# wand                         8480                  60                 110
#
#                max_price_zscore_3  max_price_IQR_70  max_price_IQR_80  \
# item_category
# amulet                        690                11                11
# belt                        20000                 6                11
# boots                        8100                 6                11
# bow                         34500                 6                11
# chest                        1102                 6                11
# claw                         8395                 6                11
# dagger                        243                 8                11
# gloves                       1080                 8                11
# helmet                        165                 6                11
# jewels                      76923                11                18
# oneaxe                       1920                 6                11
# onemace                      1053                11                23
# onesword                      586                 6                11
# quiver                         90                 6                11
# ring                       123123                 8                11
# wand                          170                 6                11
#
#                max_price_IQR_90
# item_category
# amulet                       23
# belt                         23
# boots                        24
# bow                          24
# chest                        36
# claw                         24
# dagger                       36
# gloves                       29
# helmet                       24
# jewels                       36
# oneaxe                       24
# onemace                      62
# onesword                     34
# quiver                       24
# ring                         23
# wand                         24

# %%
compare_categories_df = compare_categories_df.drop(['max_price_outliers','max_price_IQR_70','max_price_IQR_80','max_price_IQR_90'],axis=1)

# %%
compare_categories_df
# Out:
#                max_price_zscore_1  max_price_zscore_2  max_price_zscore_3
# item_category
# amulet                      231.0             462.000             690.000
# belt                       4830.0            4830.000           20000.000
# boots                      8100.0            8100.000            8100.000
# bow                       34500.0           34500.000           34500.000
# chest                       360.0             728.914            1102.487
# claw                       3311.0            8395.865            8395.865
# dagger                       90.0             169.613             243.000
# gloves                      364.5             719.915            1080.000
# helmet                       60.0             114.000             165.000
# jewels                     6000.0            6000.000           76923.000
# oneaxe                      648.0            1300.000            1920.000
# onemace                     364.5             693.000            1053.000
# onesword                    202.5             390.000             586.500
# quiver                       36.0              65.000              90.000
# ring                     123123.0          123123.000          123123.000
# wand                         60.0             110.000             170.000

# %% [markdown]
# ## It becomes clear that weapons have lower count than armour here

# %% [markdown]
# ### It also becomes clear that z_score_2 gives as better price_variance and price_max

# %%
for key_item_category, type_of_df in dfs_per_category.items():
    print("count for category -{}- = {}".format(key_item_category,type_of_df['stats_zscore_2.csv'].loc['price_amount','count']))

# %%
for key_item_category, type_of_df in dfs_per_category.items():
    print("\n\nStats for {}".format(key_item_category))
    
    for df_category,df in type_of_df.items():
        
        if 'zscore' in df_category:
            print("\t\tPrice stats for {}".format(df_category))
            
            df.loc['price_amount',['variance','mean','max']]
# Out:
# Stats for AMULET
# 		Price stats for stats_zscore_1.csv
# variance    185.140
# mean          5.455
# max         231.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    346.079
# mean          5.945
# max         462.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    432.998
# mean          6.095
# max         690.000
# Name: price_amount, dtype: float64
# Stats for BELT
# 		Price stats for stats_zscore_1.csv
# variance    1154.042
# mean           5.735
# max         4830.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    1154.042
# mean           5.735
# max         4830.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance     2825.166
# mean            5.818
# max         20000.000
# Name: price_amount, dtype: float64
# Stats for BOOTS
# 		Price stats for stats_zscore_1.csv
# variance    1009.495
# mean           5.374
# max         8100.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    1009.495
# mean           5.374
# max         8100.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    1009.495
# mean           5.374
# max         8100.000
# Name: price_amount, dtype: float64
# Stats for BOW
# 		Price stats for stats_zscore_1.csv
# variance    57979.708
# mean            8.224
# max         34500.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    57979.708
# mean            8.224
# max         34500.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    57979.708
# mean            8.224
# max         34500.000
# Name: price_amount, dtype: float64
# Stats for CHEST
# 		Price stats for stats_zscore_1.csv
# variance    450.914
# mean          7.252
# max         360.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    650.397
# mean          7.632
# max         728.914
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance     881.570
# mean           7.896
# max         1102.487
# Name: price_amount, dtype: float64
# Stats for CLAW
# 		Price stats for stats_zscore_1.csv
# variance    4088.632
# mean           9.784
# max         3311.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    6734.117
# mean          10.099
# max         8395.865
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    6734.117
# mean          10.099
# max         8395.865
# Name: price_amount, dtype: float64
# Stats for DAGGER
# 		Price stats for stats_zscore_1.csv
# variance    141.004
# mean          5.694
# max          90.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    294.621
# mean          6.894
# max         169.613
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    422.659
# mean          7.533
# max         243.000
# Name: price_amount, dtype: float64
# Stats for GLOVES
# 		Price stats for stats_zscore_1.csv
# variance    297.298
# mean          6.106
# max         364.500
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    433.192
# mean          6.387
# max         719.915
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance     493.239
# mean           6.457
# max         1080.000
# Name: price_amount, dtype: float64
# Stats for HELMET
# 		Price stats for stats_zscore_1.csv
# variance    55.855
# mean         4.174
# max         60.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    103.831
# mean          4.818
# max         114.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    169.646
# mean          5.309
# max         165.000
# Name: price_amount, dtype: float64
# Stats for JEWELS
# 		Price stats for stats_zscore_1.csv
# variance    1083.939
# mean           7.337
# max         6000.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    1083.939
# mean           7.337
# max         6000.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    31684.086
# mean            7.735
# max         76923.000
# Name: price_amount, dtype: float64
# Stats for ONEAXE
# 		Price stats for stats_zscore_1.csv
# variance    985.154
# mean          7.769
# max         648.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    1522.282
# mean           8.341
# max         1300.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    1669.916
# mean           8.418
# max         1920.000
# Name: price_amount, dtype: float64
# Stats for ONEMACE
# 		Price stats for stats_zscore_1.csv
# variance    1097.323
# mean          11.463
# max          364.500
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    1765.532
# mean          12.811
# max          693.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    2354.786
# mean          13.505
# max         1053.000
# Name: price_amount, dtype: float64
# Stats for ONESWORD
# 		Price stats for stats_zscore_1.csv
# variance    337.344
# mean          6.401
# max         202.500
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    897.053
# mean          8.383
# max         390.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    1481.982
# mean           9.609
# max          586.500
# Name: price_amount, dtype: float64
# Stats for QUIVER
# 		Price stats for stats_zscore_1.csv
# variance    21.173
# mean         3.241
# max         36.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance    40.052
# mean         3.645
# max         65.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    68.059
# mean         4.013
# max         90.000
# Name: price_amount, dtype: float64
# Stats for RING
# 		Price stats for stats_zscore_1.csv
# variance     62843.967
# mean             6.306
# max         123123.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance     62843.967
# mean             6.306
# max         123123.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance     62843.967
# mean             6.306
# max         123123.000
# Name: price_amount, dtype: float64
# Stats for WAND
# 		Price stats for stats_zscore_1.csv
# variance    42.575
# mean         3.608
# max         60.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_2.csv
# variance     77.205
# mean          4.071
# max         110.000
# Name: price_amount, dtype: float64
# 		Price stats for stats_zscore_3.csv
# variance    129.349
# mean          4.447
# max         170.000
# Name: price_amount, dtype: float64

# %%
helmet_df = dfs_per_category['chest']['stats_zscore_2.csv']
one_percent = helmet_df.loc['date_day','count']*0.01
# print("features with corr > 0.1 and <-0.1: {}".format(helmet_df.loc[abs(helmet_df['corr_kend_price'])>0.1]))
helmet_df.loc[abs(helmet_df['corr_kend_price'])>0.09].loc[helmet_df['count'] > one_percent]
helmet_df.loc[abs(helmet_df['corr_spear_price'])>0.09]
helmet_df['corr_spear_price'].nlargest(50)
# Out:
#                                                  count     mean      std  \
# Unnamed: 0
# Armour                                           70033  646.720  345.837
# Energy Shield                                    64333  131.017   82.892
# Evasion Rating                                   57795  577.876  312.371
# Quality                                         138121    2.643    6.232
# corrupted                                       138121    0.175    0.380
# date_day                                        138121    6.046    1.859
# days_in_snapshot                                138121    1.110    1.388
# ex_# to armour                                   31142   82.956   96.306
# ex_# to dexterity                                18708   25.332   10.991
# ex_# to intelligence                             20280   25.531   11.221
# ex_# to maximum energy shield                    28738   33.135   26.893
# ex_# to maximum life                            105240   68.378   35.785
# ex_# to strength                                 23306   25.667   11.118
# ex_#% increased armour and evasion                8655   41.767   25.497
# ex_#% increased energy shield                    13159   46.067   27.165
# ex_#% increased evasion rating                   13537   43.677   26.099
# ex_#% to cold resistance                         57551   26.181   11.285
# ex_#% to fire resistance                         57736   26.301   11.208
# ex_#% to lightning resistance                    56786   26.285   11.312
# ex_conv_rate                                    138121   69.293    9.436
# ex_recover #% of maximum energy shield on kill    1487    4.171    1.076
# influence                                        10438    1.368    0.482
# item_level                                      138121   68.265   14.045
# price_amount                                    138121    7.632   25.503
# sockets_number                                  138121    3.592    1.637
#
#                                                    min    25%    50%    75%  \
# Unnamed: 0
# Armour                                          19.000  385.0  575.0  841.0
# Energy Shield                                    3.000   75.0  109.0  163.0
# Evasion Rating                                  27.000  353.0  498.0  737.0
# Quality                                          0.000    0.0    0.0    0.0
# corrupted                                        0.000    0.0    0.0    0.0
# date_day                                         4.000    4.0    6.0    7.0
# days_in_snapshot                                 0.000    0.0    1.0    2.0
# ex_# to armour                                   3.000   19.0   42.0   98.0
# ex_# to dexterity                                8.000   16.0   25.0   34.0
# ex_# to intelligence                             8.000   16.0   25.0   34.0
# ex_# to maximum energy shield                    3.000   11.0   22.0   55.0
# ex_# to maximum life                             3.000   35.0   71.0   97.0
# ex_# to strength                                 8.000   16.0   25.0   34.0
# ex_#% increased armour and evasion               6.000   22.0   35.0   60.0
# ex_#% increased energy shield                    6.000   24.0   38.0   67.0
# ex_#% increased evasion rating                   6.000   23.0   36.0   63.0
# ex_#% to cold resistance                         6.000   17.0   26.0   36.0
# ex_#% to fire resistance                         6.000   17.0   26.0   36.0
# ex_#% to lightning resistance                    6.000   17.0   26.0   36.0
# ex_conv_rate                                    60.000   60.0   64.0   77.0
# ex_recover #% of maximum energy shield on kill   3.000    3.0    4.0    5.0
# influence                                        1.000    1.0    1.0    2.0
# item_level                                       1.000   65.0   72.0   75.0
# price_amount                                     0.062    1.0    1.0    5.0
# sockets_number                                   1.000    2.0    3.0    5.0
#
#                                                      max  median    variance  \
# Unnamed: 0
# Armour                                          2634.000   575.0  119603.061
# Energy Shield                                    639.000   109.0    6871.007
# Evasion Rating                                  2534.000   498.0   97575.426
# Quality                                           30.000     0.0      38.844
# corrupted                                          1.000     0.0       0.144
# date_day                                          10.000     6.0       3.457
# days_in_snapshot                                   6.000     1.0       1.928
# ex_# to armour                                   505.000    42.0    9274.844
# ex_# to dexterity                                 55.000    25.0     120.811
# ex_# to intelligence                              57.000    25.0     125.903
# ex_# to maximum energy shield                    127.000    22.0     723.208
# ex_# to maximum life                             165.000    71.0    1280.554
# ex_# to strength                                  55.000    25.0     123.608
# ex_#% increased armour and evasion               149.000    35.0     650.114
# ex_#% increased energy shield                    150.000    38.0     737.910
# ex_#% increased evasion rating                   137.000    36.0     681.150
# ex_#% to cold resistance                          48.000    26.0     127.346
# ex_#% to fire resistance                          48.000    26.0     125.628
# ex_#% to lightning resistance                     48.000    26.0     127.967
# ex_conv_rate                                      89.989    64.0      89.037
# ex_recover #% of maximum energy shield on kill     6.000     4.0       1.157
# influence                                          2.000     1.0       0.233
# item_level                                       100.000    72.0     197.262
# price_amount                                     728.914     1.0     650.397
# sockets_number                                     6.000     3.0       2.680
#
#                                                 corr_kend_price  \
# Unnamed: 0
# Armour                                                    0.121
# Energy Shield                                             0.102
# Evasion Rating                                            0.133
# Quality                                                   0.147
# corrupted                                                 0.236
# date_day                                                  0.122
# days_in_snapshot                                         -0.096
# ex_# to armour                                            0.108
# ex_# to dexterity                                         0.115
# ex_# to intelligence                                      0.105
# ex_# to maximum energy shield                             0.127
# ex_# to maximum life                                      0.192
# ex_# to strength                                          0.109
# ex_#% increased armour and evasion                        0.104
# ex_#% increased energy shield                             0.129
# ex_#% increased evasion rating                            0.094
# ex_#% to cold resistance                                  0.137
# ex_#% to fire resistance                                  0.136
# ex_#% to lightning resistance                             0.139
# ex_conv_rate                                              0.105
# ex_recover #% of maximum energy shield on kill            0.143
# influence                                                 0.092
# item_level                                                0.277
# price_amount                                              1.000
# sockets_number                                            0.298
#
#                                                 corr_pears_price  \
# Unnamed: 0
# Armour                                                     0.110
# Energy Shield                                              0.136
# Evasion Rating                                             0.095
# Quality                                                    0.255
# corrupted                                                  0.045
# date_day                                                   0.114
# days_in_snapshot                                          -0.085
# ex_# to armour                                             0.067
# ex_# to dexterity                                          0.080
# ex_# to intelligence                                       0.072
# ex_# to maximum energy shield                              0.131
# ex_# to maximum life                                       0.175
# ex_# to strength                                           0.086
# ex_#% increased armour and evasion                         0.095
# ex_#% increased energy shield                              0.150
# ex_#% increased evasion rating                             0.096
# ex_#% to cold resistance                                   0.101
# ex_#% to fire resistance                                   0.104
# ex_#% to lightning resistance                              0.105
# ex_conv_rate                                               0.102
# ex_recover #% of maximum energy shield on kill             0.094
# influence                                                 -0.002
# item_level                                                 0.182
# price_amount                                               1.000
# sockets_number                                             0.259
#
#                                                 corr_spear_price  \
# Unnamed: 0
# Armour                                                     0.169
# Energy Shield                                              0.141
# Evasion Rating                                             0.185
# Quality                                                    0.174
# corrupted                                                  0.270
# date_day                                                   0.155
# days_in_snapshot                                          -0.119
# ex_# to armour                                             0.151
# ex_# to dexterity                                          0.158
# ex_# to intelligence                                       0.144
# ex_# to maximum energy shield                              0.175
# ex_# to maximum life                                       0.268
# ex_# to strength                                           0.150
# ex_#% increased armour and evasion                         0.146
# ex_#% increased energy shield                              0.179
# ex_#% increased evasion rating                             0.131
# ex_#% to cold resistance                                   0.190
# ex_#% to fire resistance                                   0.188
# ex_#% to lightning resistance                              0.192
# ex_conv_rate                                               0.133
# ex_recover #% of maximum energy shield on kill             0.178
# influence                                                  0.107
# item_level                                                 0.369
# price_amount                                               1.000
# sockets_number                                             0.382
#
#                                                 percentage_to_rows
# Unnamed: 0
# Armour                                                      50.704
# Energy Shield                                               46.577
# Evasion Rating                                              41.844
# Quality                                                    100.000
# corrupted                                                  100.000
# date_day                                                   100.000
# days_in_snapshot                                           100.000
# ex_# to armour                                              22.547
# ex_# to dexterity                                           13.545
# ex_# to intelligence                                        14.683
# ex_# to maximum energy shield                               20.806
# ex_# to maximum life                                        76.194
# ex_# to strength                                            16.874
# ex_#% increased armour and evasion                           6.266
# ex_#% increased energy shield                                9.527
# ex_#% increased evasion rating                               9.801
# ex_#% to cold resistance                                    41.667
# ex_#% to fire resistance                                    41.801
# ex_#% to lightning resistance                               41.113
# ex_conv_rate                                               100.000
# ex_recover #% of maximum energy shield on kill               1.077
# influence                                                    7.557
# item_level                                                 100.000
# price_amount                                               100.000
# sockets_number                                             100.000
#                                                      count     mean      std  \
# Unnamed: 0
# Armour                                               70033  646.720  345.837
# Energy Shield                                        64333  131.017   82.892
# Evasion Rating                                       57795  577.876  312.371
# Quality                                             138121    2.643    6.232
# co_#% additional physical damage reduction whil...      20    3.900    0.788
# co_#% increased damage                                  66   45.652    3.145
# co_#% increased maximum energy shield                   22    4.818    0.795
# co_#% increased maximum life                            28    4.893    0.916
# co_#% increased spell damage                           165    6.509    2.331
# co_#% reduced cold damage taken                         16    5.125    0.885
# co_#% reduced fire damage taken                         19    4.789    0.976
# co_#% reduced lightning damage taken                    17    5.353    0.862
# corrupted                                           138121    0.175    0.380
# date_day                                            138121    6.046    1.859
# days_in_snapshot                                    138121    1.110    1.388
# ex_# life regenerated per second                     31017    5.988    4.019
# ex_# to armour                                       31142   82.956   96.306
# ex_# to dexterity                                    18708   25.332   10.991
# ex_# to evasion rating                               25313   82.975   96.821
# ex_# to intelligence                                 20280   25.531   11.221
# ex_# to maximum energy shield                        28738   33.135   26.893
# ex_# to maximum life                                105240   68.378   35.785
# ex_# to maximum mana                                 27781   39.162   14.788
# ex_# to strength                                     23306   25.667   11.118
# ex_#% chance to avoid cold damage when hit              23    6.130    0.694
# ex_#% chance to avoid fire damage when hit               6    6.833    0.753
# ex_#% chance to avoid lightning damage when hit         65    5.354    1.052
# ex_#% chance to dodge spell hits                         6    3.667    1.211
# ex_#% increased armour                               21106   44.637   26.302
# ex_#% increased armour and evasion                    8655   41.767   25.497
# ex_#% increased armour, evasion and energy shield       52   50.865   31.151
# ex_#% increased dexterity                              607    7.056    1.777
# ex_#% increased energy shield                        13159   46.067   27.165
# ex_#% increased evasion rating                       13537   43.677   26.099
# ex_#% increased intelligence                          1068    6.871    1.635
# ex_#% increased strength                               585    7.031    1.827
# ex_#% of physical damage from hits taken as col...     565    7.986    2.218
# ex_#% of physical damage from hits taken as fir...     309    7.961    2.466
# ex_#% of physical damage from hits taken as lig...     556    8.200    2.349
# ex_#% reduced reflected physical damage taken          213   22.319    4.452
# ex_#% to cold resistance                             57551   26.181   11.285
# ex_#% to fire resistance                             57736   26.301   11.208
# ex_#% to lightning resistance                        56786   26.285   11.312
# ex_attacks have #% to critical strike chance           483    0.853    0.243
# ex_conv_rate                                        138121   69.293    9.436
# ex_minions have #% increased maximum life               75   12.493    4.202
# ex_recover #% of maximum energy shield on kill        1487    4.171    1.076
# ex_recover #% of maximum mana on kill                 1377    4.171    1.070
# ex_socketed gems are supported by level # item ...    1146   10.144    0.837
# ex_spells have #% to critical strike chance            981    0.831    0.224
# im_#% to all elemental resistances                    7690   10.134    1.407
# influence                                            10438    1.368    0.482
# item_level                                          138121   68.265   14.045
# price_amount                                        138121    7.632   25.503
# sockets_number                                      138121    3.592    1.637
#
#                                                        min     25%     50%  \
# Unnamed: 0
# Armour                                              19.000  385.00  575.00
# Energy Shield                                        3.000   75.00  109.00
# Evasion Rating                                      27.000  353.00  498.00
# Quality                                              0.000    0.00    0.00
# co_#% additional physical damage reduction whil...   3.000    3.00    4.00
# co_#% increased damage                              40.000   43.00   46.00
# co_#% increased maximum energy shield                4.000    4.00    5.00
# co_#% increased maximum life                         4.000    4.00    5.00
# co_#% increased spell damage                         3.000    4.00    7.00
# co_#% reduced cold damage taken                      4.000    4.00    5.00
# co_#% reduced fire damage taken                      4.000    4.00    4.00
# co_#% reduced lightning damage taken                 4.000    5.00    6.00
# corrupted                                            0.000    0.00    0.00
# date_day                                             4.000    4.00    6.00
# days_in_snapshot                                     0.000    0.00    1.00
# ex_# life regenerated per second                     1.000    2.30    5.20
# ex_# to armour                                       3.000   19.00   42.00
# ex_# to dexterity                                    8.000   16.00   25.00
# ex_# to evasion rating                               3.000   19.00   41.00
# ex_# to intelligence                                 8.000   16.00   25.00
# ex_# to maximum energy shield                        3.000   11.00   22.00
# ex_# to maximum life                                 3.000   35.00   71.00
# ex_# to maximum mana                                15.000   26.00   39.00
# ex_# to strength                                     8.000   16.00   25.00
# ex_#% chance to avoid cold damage when hit           5.000    6.00    6.00
# ex_#% chance to avoid fire damage when hit           6.000    6.25    7.00
# ex_#% chance to avoid lightning damage when hit      4.000    5.00    5.00
# ex_#% chance to dodge spell hits                     3.000    3.00    3.00
# ex_#% increased armour                               6.000   23.00   37.00
# ex_#% increased armour and evasion                   6.000   22.00   35.00
# ex_#% increased armour, evasion and energy shield    7.000   28.75   37.50
# ex_#% increased dexterity                            5.000    6.00    7.00
# ex_#% increased energy shield                        6.000   24.00   38.00
# ex_#% increased evasion rating                       6.000   23.00   36.00
# ex_#% increased intelligence                         5.000    6.00    7.00
# ex_#% increased strength                             5.000    6.00    7.00
# ex_#% of physical damage from hits taken as col...   5.000    6.00    8.00
# ex_#% of physical damage from hits taken as fir...   5.000    6.00    8.00
# ex_#% of physical damage from hits taken as lig...   5.000    6.00    8.00
# ex_#% reduced reflected physical damage taken       15.000   18.00   22.00
# ex_#% to cold resistance                             6.000   17.00   26.00
# ex_#% to fire resistance                             6.000   17.00   26.00
# ex_#% to lightning resistance                        6.000   17.00   26.00
# ex_attacks have #% to critical strike chance         0.500    0.68    0.83
# ex_conv_rate                                        60.000   60.00   64.00
# ex_minions have #% increased maximum life            7.000    9.00   12.00
# ex_recover #% of maximum energy shield on kill       3.000    3.00    4.00
# ex_recover #% of maximum mana on kill                3.000    3.00    4.00
# ex_socketed gems are supported by level # item ...  10.000   10.00   10.00
# ex_spells have #% to critical strike chance          0.500    0.66    0.82
# im_#% to all elemental resistances                   8.000    9.00   10.00
# influence                                            1.000    1.00    1.00
# item_level                                           1.000   65.00   72.00
# price_amount                                         0.062    1.00    1.00
# sockets_number                                       1.000    2.00    3.00
#
#                                                        75%       max  median  \
# Unnamed: 0
# Armour                                              841.00  2634.000  575.00
# Energy Shield                                       163.00   639.000  109.00
# Evasion Rating                                      737.00  2534.000  498.00
# Quality                                               0.00    30.000    0.00
# co_#% additional physical damage reduction whil...    4.25     5.000    4.00
# co_#% increased damage                               49.00    50.000   46.00
# co_#% increased maximum energy shield                 5.00     6.000    5.00
# co_#% increased maximum life                          6.00     6.000    5.00
# co_#% increased spell damage                          9.00    10.000    7.00
# co_#% reduced cold damage taken                       6.00     6.000    5.00
# co_#% reduced fire damage taken                       6.00     6.000    4.00
# co_#% reduced lightning damage taken                  6.00     6.000    6.00
# corrupted                                             0.00     1.000    0.00
# date_day                                              7.00    10.000    6.00
# days_in_snapshot                                      2.00     6.000    1.00
# ex_# life regenerated per second                      9.10    25.000    5.20
# ex_# to armour                                       98.00   505.000   42.00
# ex_# to dexterity                                    34.00    55.000   25.00
# ex_# to evasion rating                               99.00   500.000   41.00
# ex_# to intelligence                                 34.00    57.000   25.00
# ex_# to maximum energy shield                        55.00   127.000   22.00
# ex_# to maximum life                                 97.00   165.000   71.00
# ex_# to maximum mana                                 51.00    73.000   39.00
# ex_# to strength                                     34.00    55.000   25.00
# ex_#% chance to avoid cold damage when hit            7.00     7.000    6.00
# ex_#% chance to avoid fire damage when hit            7.00     8.000    7.00
# ex_#% chance to avoid lightning damage when hit       6.00     8.000    5.00
# ex_#% chance to dodge spell hits                      3.75     6.000    3.00
# ex_#% increased armour                               65.00   149.000   37.00
# ex_#% increased armour and evasion                   60.00   149.000   35.00
# ex_#% increased armour, evasion and energy shield    75.00   108.000   37.50
# ex_#% increased dexterity                             8.00    12.000    7.00
# ex_#% increased energy shield                        67.00   150.000   38.00
# ex_#% increased evasion rating                       63.00   137.000   36.00
# ex_#% increased intelligence                          8.00    12.000    7.00
# ex_#% increased strength                              8.00    12.000    7.00
# ex_#% of physical damage from hits taken as col...    9.00    15.000    8.00
# ex_#% of physical damage from hits taken as fir...    9.00    15.000    8.00
# ex_#% of physical damage from hits taken as lig...   10.00    15.000    8.00
# ex_#% reduced reflected physical damage taken        26.00    30.000   22.00
# ex_#% to cold resistance                             36.00    48.000   26.00
# ex_#% to fire resistance                             36.00    48.000   26.00
# ex_#% to lightning resistance                        36.00    48.000   26.00
# ex_attacks have #% to critical strike chance          0.96     1.500    0.83
# ex_conv_rate                                         77.00    89.989   64.00
# ex_minions have #% increased maximum life            15.00    23.000   12.00
# ex_recover #% of maximum energy shield on kill        5.00     6.000    4.00
# ex_recover #% of maximum mana on kill                 5.00     6.000    4.00
# ex_socketed gems are supported by level # item ...   10.00    15.000   10.00
# ex_spells have #% to critical strike chance           0.95     1.500    0.82
# im_#% to all elemental resistances                   11.00    12.000   10.00
# influence                                             2.00     2.000    1.00
# item_level                                           75.00   100.000   72.00
# price_amount                                          5.00   728.914    1.00
# sockets_number                                        5.00     6.000    3.00
#
#                                                       variance  \
# Unnamed: 0
# Armour                                              119603.061
# Energy Shield                                         6871.007
# Evasion Rating                                       97575.426
# Quality                                                 38.844
# co_#% additional physical damage reduction whil...       0.621
# co_#% increased damage                                   9.892
# co_#% increased maximum energy shield                    0.632
# co_#% increased maximum life                             0.840
# co_#% increased spell damage                             5.434
# co_#% reduced cold damage taken                          0.783
# co_#% reduced fire damage taken                          0.953
# co_#% reduced lightning damage taken                     0.743
# corrupted                                                0.144
# date_day                                                 3.457
# days_in_snapshot                                         1.928
# ex_# life regenerated per second                        16.153
# ex_# to armour                                        9274.844
# ex_# to dexterity                                      120.811
# ex_# to evasion rating                                9374.374
# ex_# to intelligence                                   125.903
# ex_# to maximum energy shield                          723.208
# ex_# to maximum life                                  1280.554
# ex_# to maximum mana                                   218.689
# ex_# to strength                                       123.608
# ex_#% chance to avoid cold damage when hit               0.482
# ex_#% chance to avoid fire damage when hit               0.567
# ex_#% chance to avoid lightning damage when hit          1.107
# ex_#% chance to dodge spell hits                         1.467
# ex_#% increased armour                                 691.820
# ex_#% increased armour and evasion                     650.114
# ex_#% increased armour, evasion and energy shield      970.393
# ex_#% increased dexterity                                3.159
# ex_#% increased energy shield                          737.910
# ex_#% increased evasion rating                         681.150
# ex_#% increased intelligence                             2.673
# ex_#% increased strength                                 3.338
# ex_#% of physical damage from hits taken as col...       4.918
# ex_#% of physical damage from hits taken as fir...       6.083
# ex_#% of physical damage from hits taken as lig...       5.519
# ex_#% reduced reflected physical damage taken           19.822
# ex_#% to cold resistance                               127.346
# ex_#% to fire resistance                               125.628
# ex_#% to lightning resistance                          127.967
# ex_attacks have #% to critical strike chance             0.059
# ex_conv_rate                                            89.037
# ex_minions have #% increased maximum life               17.659
# ex_recover #% of maximum energy shield on kill           1.157
# ex_recover #% of maximum mana on kill                    1.145
# ex_socketed gems are supported by level # item ...       0.700
# ex_spells have #% to critical strike chance              0.050
# im_#% to all elemental resistances                       1.979
# influence                                                0.233
# item_level                                             197.262
# price_amount                                           650.397
# sockets_number                                           2.680
#
#                                                     corr_kend_price  \
# Unnamed: 0
# Armour                                                        0.121
# Energy Shield                                                 0.102
# Evasion Rating                                                0.133
# Quality                                                       0.147
# co_#% additional physical damage reduction whil...            0.084
# co_#% increased damage                                        0.157
# co_#% increased maximum energy shield                         0.182
# co_#% increased maximum life                                 -0.192
# co_#% increased spell damage                                 -0.101
# co_#% reduced cold damage taken                              -0.127
# co_#% reduced fire damage taken                               0.504
# co_#% reduced lightning damage taken                          0.325
# corrupted                                                     0.236
# date_day                                                      0.122
# days_in_snapshot                                             -0.096
# ex_# life regenerated per second                              0.081
# ex_# to armour                                                0.108
# ex_# to dexterity                                             0.115
# ex_# to evasion rating                                        0.090
# ex_# to intelligence                                          0.105
# ex_# to maximum energy shield                                 0.127
# ex_# to maximum life                                          0.192
# ex_# to maximum mana                                          0.080
# ex_# to strength                                              0.109
# ex_#% chance to avoid cold damage when hit                    0.233
# ex_#% chance to avoid fire damage when hit                   -0.402
# ex_#% chance to avoid lightning damage when hit               0.402
# ex_#% chance to dodge spell hits                             -0.356
# ex_#% increased armour                                        0.082
# ex_#% increased armour and evasion                            0.104
# ex_#% increased armour, evasion and energy shield            -0.182
# ex_#% increased dexterity                                     0.201
# ex_#% increased energy shield                                 0.129
# ex_#% increased evasion rating                                0.094
# ex_#% increased intelligence                                  0.138
# ex_#% increased strength                                      0.111
# ex_#% of physical damage from hits taken as col...            0.115
# ex_#% of physical damage from hits taken as fir...            0.118
# ex_#% of physical damage from hits taken as lig...            0.149
# ex_#% reduced reflected physical damage taken                 0.080
# ex_#% to cold resistance                                      0.137
# ex_#% to fire resistance                                      0.136
# ex_#% to lightning resistance                                 0.139
# ex_attacks have #% to critical strike chance                  0.237
# ex_conv_rate                                                  0.105
# ex_minions have #% increased maximum life                     0.465
# ex_recover #% of maximum energy shield on kill                0.143
# ex_recover #% of maximum mana on kill                         0.141
# ex_socketed gems are supported by level # item ...            0.201
# ex_spells have #% to critical strike chance                   0.254
# im_#% to all elemental resistances                            0.082
# influence                                                     0.092
# item_level                                                    0.277
# price_amount                                                  1.000
# sockets_number                                                0.298
#
#                                                     corr_pears_price  \
# Unnamed: 0
# Armour                                                         0.110
# Energy Shield                                                  0.136
# Evasion Rating                                                 0.095
# Quality                                                        0.255
# co_#% additional physical damage reduction whil...             0.242
# co_#% increased damage                                         0.093
# co_#% increased maximum energy shield                          0.431
# co_#% increased maximum life                                  -0.290
# co_#% increased spell damage                                  -0.132
# co_#% reduced cold damage taken                               -0.066
# co_#% reduced fire damage taken                                0.629
# co_#% reduced lightning damage taken                           0.257
# corrupted                                                      0.045
# date_day                                                       0.114
# days_in_snapshot                                              -0.085
# ex_# life regenerated per second                               0.084
# ex_# to armour                                                 0.067
# ex_# to dexterity                                              0.080
# ex_# to evasion rating                                         0.069
# ex_# to intelligence                                           0.072
# ex_# to maximum energy shield                                  0.131
# ex_# to maximum life                                           0.175
# ex_# to maximum mana                                           0.032
# ex_# to strength                                               0.086
# ex_#% chance to avoid cold damage when hit                     0.394
# ex_#% chance to avoid fire damage when hit                    -0.525
# ex_#% chance to avoid lightning damage when hit                0.359
# ex_#% chance to dodge spell hits                              -0.387
# ex_#% increased armour                                         0.056
# ex_#% increased armour and evasion                             0.095
# ex_#% increased armour, evasion and energy shield             -0.205
# ex_#% increased dexterity                                      0.158
# ex_#% increased energy shield                                  0.150
# ex_#% increased evasion rating                                 0.096
# ex_#% increased intelligence                                   0.188
# ex_#% increased strength                                       0.167
# ex_#% of physical damage from hits taken as col...             0.164
# ex_#% of physical damage from hits taken as fir...             0.061
# ex_#% of physical damage from hits taken as lig...             0.208
# ex_#% reduced reflected physical damage taken                  0.046
# ex_#% to cold resistance                                       0.101
# ex_#% to fire resistance                                       0.104
# ex_#% to lightning resistance                                  0.105
# ex_attacks have #% to critical strike chance                   0.340
# ex_conv_rate                                                   0.102
# ex_minions have #% increased maximum life                      0.410
# ex_recover #% of maximum energy shield on kill                 0.094
# ex_recover #% of maximum mana on kill                          0.029
# ex_socketed gems are supported by level # item ...             0.135
# ex_spells have #% to critical strike chance                    0.362
# im_#% to all elemental resistances                             0.108
# influence                                                     -0.002
# item_level                                                     0.182
# price_amount                                                   1.000
# sockets_number                                                 0.259
#
#                                                     corr_spear_price  \
# Unnamed: 0
# Armour                                                         0.169
# Energy Shield                                                  0.141
# Evasion Rating                                                 0.185
# Quality                                                        0.174
# co_#% additional physical damage reduction whil...             0.104
# co_#% increased damage                                         0.204
# co_#% increased maximum energy shield                          0.215
# co_#% increased maximum life                                  -0.242
# co_#% increased spell damage                                  -0.129
# co_#% reduced cold damage taken                               -0.143
# co_#% reduced fire damage taken                                0.602
# co_#% reduced lightning damage taken                           0.388
# corrupted                                                      0.270
# date_day                                                       0.155
# days_in_snapshot                                              -0.119
# ex_# life regenerated per second                               0.113
# ex_# to armour                                                 0.151
# ex_# to dexterity                                              0.158
# ex_# to evasion rating                                         0.127
# ex_# to intelligence                                           0.144
# ex_# to maximum energy shield                                  0.175
# ex_# to maximum life                                           0.268
# ex_# to maximum mana                                           0.111
# ex_# to strength                                               0.150
# ex_#% chance to avoid cold damage when hit                     0.280
# ex_#% chance to avoid fire damage when hit                    -0.420
# ex_#% chance to avoid lightning damage when hit                0.464
# ex_#% chance to dodge spell hits                              -0.412
# ex_#% increased armour                                         0.114
# ex_#% increased armour and evasion                             0.146
# ex_#% increased armour, evasion and energy shield             -0.231
# ex_#% increased dexterity                                      0.259
# ex_#% increased energy shield                                  0.179
# ex_#% increased evasion rating                                 0.131
# ex_#% increased intelligence                                   0.176
# ex_#% increased strength                                       0.146
# ex_#% of physical damage from hits taken as col...             0.152
# ex_#% of physical damage from hits taken as fir...             0.157
# ex_#% of physical damage from hits taken as lig...             0.201
# ex_#% reduced reflected physical damage taken                  0.111
# ex_#% to cold resistance                                       0.190
# ex_#% to fire resistance                                       0.188
# ex_#% to lightning resistance                                  0.192
# ex_attacks have #% to critical strike chance                   0.333
# ex_conv_rate                                                   0.133
# ex_minions have #% increased maximum life                      0.597
# ex_recover #% of maximum energy shield on kill                 0.178
# ex_recover #% of maximum mana on kill                          0.176
# ex_socketed gems are supported by level # item ...             0.231
# ex_spells have #% to critical strike chance                    0.355
# im_#% to all elemental resistances                             0.104
# influence                                                      0.107
# item_level                                                     0.369
# price_amount                                                   1.000
# sockets_number                                                 0.382
#
#                                                     percentage_to_rows
# Unnamed: 0
# Armour                                                          50.704
# Energy Shield                                                   46.577
# Evasion Rating                                                  41.844
# Quality                                                        100.000
# co_#% additional physical damage reduction whil...               0.014
# co_#% increased damage                                           0.048
# co_#% increased maximum energy shield                            0.016
# co_#% increased maximum life                                     0.020
# co_#% increased spell damage                                     0.119
# co_#% reduced cold damage taken                                  0.012
# co_#% reduced fire damage taken                                  0.014
# co_#% reduced lightning damage taken                             0.012
# corrupted                                                      100.000
# date_day                                                       100.000
# days_in_snapshot                                               100.000
# ex_# life regenerated per second                                22.456
# ex_# to armour                                                  22.547
# ex_# to dexterity                                               13.545
# ex_# to evasion rating                                          18.327
# ex_# to intelligence                                            14.683
# ex_# to maximum energy shield                                   20.806
# ex_# to maximum life                                            76.194
# ex_# to maximum mana                                            20.114
# ex_# to strength                                                16.874
# ex_#% chance to avoid cold damage when hit                       0.017
# ex_#% chance to avoid fire damage when hit                       0.004
# ex_#% chance to avoid lightning damage when hit                  0.047
# ex_#% chance to dodge spell hits                                 0.004
# ex_#% increased armour                                          15.281
# ex_#% increased armour and evasion                               6.266
# ex_#% increased armour, evasion and energy shield                0.038
# ex_#% increased dexterity                                        0.439
# ex_#% increased energy shield                                    9.527
# ex_#% increased evasion rating                                   9.801
# ex_#% increased intelligence                                     0.773
# ex_#% increased strength                                         0.424
# ex_#% of physical damage from hits taken as col...               0.409
# ex_#% of physical damage from hits taken as fir...               0.224
# ex_#% of physical damage from hits taken as lig...               0.403
# ex_#% reduced reflected physical damage taken                    0.154
# ex_#% to cold resistance                                        41.667
# ex_#% to fire resistance                                        41.801
# ex_#% to lightning resistance                                   41.113
# ex_attacks have #% to critical strike chance                     0.350
# ex_conv_rate                                                   100.000
# ex_minions have #% increased maximum life                        0.054
# ex_recover #% of maximum energy shield on kill                   1.077
# ex_recover #% of maximum mana on kill                            0.997
# ex_socketed gems are supported by level # item ...               0.830
# ex_spells have #% to critical strike chance                      0.710
# im_#% to all elemental resistances                               5.568
# influence                                                        7.557
# item_level                                                     100.000
# price_amount                                                   100.000
# sockets_number                                                 100.000
# Unnamed: 0
# price_amount                                                    1.000
# co_#% reduced fire damage taken                                 0.602
# ex_minions have #% increased maximum life                       0.597
# ex_#% chance to avoid lightning damage when hit                 0.464
# co_#% reduced lightning damage taken                            0.388
# sockets_number                                                  0.382
# item_level                                                      0.369
# ex_spells have #% to critical strike chance                     0.355
# ex_attacks have #% to critical strike chance                    0.333
# ex_#% chance to avoid cold damage when hit                      0.280
# corrupted                                                       0.270
# ex_# to maximum life                                            0.268
# ex_#% increased dexterity                                       0.259
# ex_socketed gems are supported by level # item rarity           0.231
# co_#% increased maximum energy shield                           0.215
# co_#% increased damage                                          0.204
# ex_#% of physical damage from hits taken as lightning damage    0.201
# ex_#% to lightning resistance                                   0.192
# ex_#% to cold resistance                                        0.190
# ex_#% to fire resistance                                        0.188
# Evasion Rating                                                  0.185
# ex_#% increased energy shield                                   0.179
# ex_recover #% of maximum energy shield on kill                  0.178
# ex_#% increased intelligence                                    0.176
# ex_recover #% of maximum mana on kill                           0.176
# ex_# to maximum energy shield                                   0.175
# Quality                                                         0.174
# Armour                                                          0.169
# ex_# to dexterity                                               0.158
# ex_#% of physical damage from hits taken as fire damage         0.157
# date_day                                                        0.155
# ex_#% of physical damage from hits taken as cold damage         0.152
# ex_# to armour                                                  0.151
# ex_# to strength                                                0.150
# ex_#% increased armour and evasion                              0.146
# ex_#% increased strength                                        0.146
# ex_# to intelligence                                            0.144
# Energy Shield                                                   0.141
# ex_conv_rate                                                    0.133
# ex_#% increased evasion rating                                  0.131
# ex_# to evasion rating                                          0.127
# ex_#% increased armour                                          0.114
# ex_# life regenerated per second                                0.113
# ex_# to maximum mana                                            0.111
# ex_#% reduced reflected physical damage taken                   0.111
# influence                                                       0.107
# co_#% additional physical damage reduction while stationary     0.104
# im_#% to all elemental resistances                              0.104
# ex_#% increased evasion and energy shield                       0.087
# ex_#% of energy shield regenerated per second                   0.086
# Name: corr_spear_price, dtype: float64

# %%
for key_item_category, type_of_df in dfs_per_category.items():
    print("\n\n{} in stats_zscore_2.csv".format(key_item_category.upper()))
    
    for df_category,df in type_of_df.items():
        
        if 'stats_zscore_2.csv' in df_category:
            #print("\t\tPrice stats for {}".format(df_category))
            print("number of features {}".format(df.shape[0]))
            print("number of features with corr > 0.1 and <-0.1: {}".format(df.loc[abs(df['corr_kend_price'])>0.1].loc[df['price_amount']].shape[0]))
            #df.loc['price_amount',['variance','mean','max']]
# Out:
# AMULET in stats_zscore_2.csv
# number of features 170
# number of features with corr > 0.1 and <-0.1: 44
#
#
# BELT in stats_zscore_2.csv
# number of features 99
# number of features with corr > 0.1 and <-0.1: 31
#
#
# BOOTS in stats_zscore_2.csv
# number of features 106
# number of features with corr > 0.1 and <-0.1: 37
#
#
# BOW in stats_zscore_2.csv
# number of features 106
# number of features with corr > 0.1 and <-0.1: 47
#
#
# CHEST in stats_zscore_2.csv
# number of features 94
# number of features with corr > 0.1 and <-0.1: 45
#
#
# CLAW in stats_zscore_2.csv
# number of features 109
# number of features with corr > 0.1 and <-0.1: 65
#
#
# DAGGER in stats_zscore_2.csv
# number of features 131
# number of features with corr > 0.1 and <-0.1: 55
#
#
# GLOVES in stats_zscore_2.csv
# number of features 179
# number of features with corr > 0.1 and <-0.1: 53
#
#
# HELMET in stats_zscore_2.csv
# number of features 570
# number of features with corr > 0.1 and <-0.1: 51
#
#
# JEWELS in stats_zscore_2.csv
# number of features 150
# number of features with corr > 0.1 and <-0.1: 6
#
#
# ONEAXE in stats_zscore_2.csv
# number of features 99
# number of features with corr > 0.1 and <-0.1: 52
#
#
# ONEMACE in stats_zscore_2.csv
# number of features 152
# number of features with corr > 0.1 and <-0.1: 78
#
#
# ONESWORD in stats_zscore_2.csv
# number of features 120
# number of features with corr > 0.1 and <-0.1: 59
#
#
# QUIVER in stats_zscore_2.csv
# number of features 77
# number of features with corr > 0.1 and <-0.1: 24
#
#
# RING in stats_zscore_2.csv
# number of features 139
# number of features with corr > 0.1 and <-0.1: 46
#
#
# WAND in stats_zscore_2.csv
# number of features 124
# number of features with corr > 0.1 and <-0.1: 51

# %%
columns = ['item_category','stats_zscore_1.csv','stats_zscore_2.csv','stats_zscore_3.csv']

compare_categories_df =  pd.DataFrame(columns=columns)

for key_item_category, type_of_df in dfs_per_category.items():
    
    category_dict = {'item_category':key_item_category}
    
    for df_category,df in type_of_df.items():
        category_dict[df_category] =df.loc['price_amount','max']
    compare_categories_df = compare_categories_df.append(category_dict,ignore_index=True)

compare_categories_df = compare_categories_df.set_index('item_category')
